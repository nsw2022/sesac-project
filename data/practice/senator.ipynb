# %%
import requests
import pandas as pd
import itertools

# %%
# 발급 받은 API 키
YOUR_API_KEY = '640b6edf35bb47f280aac61745395c9e'
# 국회의원 발의법률안 데이터 아이디
data_id = 'nzmimeepazxkubdpn'

# %%
print(requests.post("https://naver.com").text)
# Out:
#    <!doctype html> <html lang="ko" class="fzoom"> <head> <meta charset="utf-8"> <meta name="Referrer" content="origin"> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <title>NAVER</title> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <link rel="shortcut icon" type="image/x-icon" href="/favicon.ico?1"> <link rel="apple-touch-icon-precomposed" href="https://s.pstatic.net/static/www/nFavicon96.png"/> <link rel="apple-touch-icon" sizes="114x114" href="https://s.pstatic.net/static/www/u/2014/0328/mma_204243574.png"/> <link rel="apple-touch-icon" href="https://s.pstatic.net/static/www/u/2014/0328/mma_20432863.png"/> <link rel="stylesheet" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_231130.css"> <script>window.gladsdk=window.gladsdk||{},window.gladsdk.cmd=window.gladsdk.cmd||[],window.ndpsdk=window.ndpsdk||{},window.ndpsdk.cmd=window.ndpsdk.cmd||[],window.ndpsdk.polyfill=window.ndpsdk.polyfill||{cmd:[]};var g_ssc="navertop.v5";window.nsc=g_ssc,window.nmain=window.nmain||{},window.nmain.jsOrigin="www"</script> <script async src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-loader.js"></script> <script async src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script> <script src="https://ssl.pstatic.net/tveta/libs/assets/js/pc/main/min/pc.veta.core.min.js" defer="defer"></script>  <script>
# window["EAGER-DATA"] = window["EAGER-DATA"] || {};
# window["EAGER-DATA"]["PC-FEED-WRAPPER"] = {"@type":"BLOCK","blocks":[{"@type":"BLOCK","blocks":[{"@type":"PC-FEED-BLOCK","materials":[{"@type":"MATERIAL-PC-FEED","title":"12시네점심","url":"https://comic.naver.com/webtoon/list?titleId=819217","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fshared-comic.pstatic.net%2Fthumb%2Fwebtoon%2F819217%2Fthumbnail%2Fthumbnail_IMAG21_2dd78d6c-ba3d-4d1d-8b98-30c13d90144d.jpg%22&type=nf216_280&service=navermain"},"desc":"조석","webtoonIcon":{"newest":true,"adult":false,"up":true,"dailyPass":false,"seriesEdition":false},"_id":"654ad80598c6dbca70ba6c64"},{"@type":"MATERIAL-PC-FEED","title":"화산귀환","url":"https://comic.naver.com/webtoon/list?titleId=769209","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fshared-comic.pstatic.net%2Fthumb%2Fwebtoon%2F769209%2Fthumbnail%2Fthumbnail_IMAG21_3511dcdd-6e33-4171-8839-598d6d266215.jpg%22&type=nf216_280&service=navermain"},"desc":"LICO / 비가","webtoonIcon":{"newest":false,"adult":false,"up":true,"dailyPass":false,"seriesEdition":false},"_id":"654ad80598c6dbca70ba6c65"},{"@type":"MATERIAL-PC-FEED","title":"전지적 독자 시점","url":"https://comic.naver.com/webtoon/list?titleId=747269","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fshared-comic.pstatic.net%2Fthumb%2Fwebtoon%2F747269%2Fthumbnail%2Fthumbnail_IMAG21_aabd9952-ff45-47a2-a543-33f19a5c6708.jpg%22&type=nf216_280&service=navermain"},"desc":"UMI / 슬리피-C / 싱숑","webtoonIcon":{"newest":false,"adult":false,"up":true,"dailyPass":false,"seriesEdition":false},"_id":"654ad80598c6dbca70ba6c66"},{"@type":"MATERIAL-PC-FEED","title":"무직백수 계백순","url":"https://comic.naver.com/webtoon/list?titleId=811721","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fshared-comic.pstatic.net%2Fthumb%2Fwebtoon%2F811721%2Fthumbnail%2Fthumbnail_IMAG21_9a2a959a-666b-4156-8e4f-db64dfe319c6.jpg%22&type=nf216_280&service=navermain"},"desc":"지발","webtoonIcon":{"newest":false,"adult":false,"up":true,"dailyPass":false,"seriesEdition":false},"_id":"654ad80598c6dbca70ba6c67"},{"@type":"MATERIAL-PC-FEED","title":"백XX","url":"https://comic.naver.com/webtoon/list?titleId=804862","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fshared-comic.pstatic.net%2Fthumb%2Fwebtoon%2F804862%2Fthumbnail%2Fthumbnail_IMAG21_f1b2f920-5c10-4155-a547-0c25a7132d8f.jpeg%22&type=nf216_280&service=navermain"},"desc":"박태준 만화회사, 병장 / 펀치킥","webtoonIcon":{"newest":false,"adult":false,"up":true,"dailyPass":false,"seriesEdition":false},"_id":"654ad80598c6dbca70ba6c68"},{"@type":"MATERIAL-PC-FEED","title":"헬퍼 2 : 킬베로스","url":"https://comic.naver.com/webtoon/list?titleId=670143","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fshared-comic.pstatic.net%2Fthumb%2Fwebtoon%2F670143%2Fthumbnail%2Fthumbnail_IMAG21_12d5d293-d54d-4022-8e00-c97c5779c701.jpg%22&type=nf216_280&service=navermain"},"desc":"삭","webtoonIcon":{"newest":false,"adult":true,"up":true,"dailyPass":false,"seriesEdition":false},"_id":"654ad80598c6dbca70ba6c69"},{"@type":"MATERIAL-PC-FEED","title":"울어 봐, 빌어도 좋고","url":"https://comic.naver.com/webtoon/list?titleId=814826","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fshared-comic.pstatic.net%2Fthumb%2Fwebtoon%2F814826%2Fthumbnail%2Fthumbnail_IMAG21_1de7535f-9088-4f21-8b16-413cb1e66307.jpg%22&type=nf216_280&service=navermain"},"desc":"반지 / 솔체","webtoonIcon":{"newest":false,"adult":false,"up":true,"dailyPass":false,"seriesEdition":false},"_id":"654ad80598c6dbca70ba6c6a"},{"@type":"MATERIAL-PC-FEED","title":"일렉시드","url":"https://comic.naver.com/webtoon/list?titleId=717481","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fshared-comic.pstatic.net%2Fthumb%2Fwebtoon%2F717481%2Fthumbnail%2Fthumbnail_IMAG21_3545800975505057126.jpg%22&type=nf216_280&service=navermain"},"desc":"손제호 / 제나","webtoonIcon":{"newest":false,"adult":false,"up":true,"dailyPass":false,"seriesEdition":false},"_id":"654ad80 ...
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-SPECIAL-LOGO"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[],"_id":"6433d8e3a10d3006850274e8","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-SPECIAL-LOGO","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"d476ab7d-b4d3-11ee-ac5f-8bf73c3e7b5a","@provider":"lambda","@lastModifiedAt":[2024,1,17,1,0,39,99000000]}
# window["EAGER-DATA"]["PC-MEDIA-WRAPPER"] = {"@type":"PC-MEDIA-CONTENTS-BLOCK","blocks":[{"@type":"BLOCK","blocks":[{"@type":"PC-NEWSSTAND-BLOCK","blocks":[{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"907","name":"경북매일신문","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/907.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/907.png"},"showThumbnailView":true,"showListView":true,"regDate":"20240117 09:40:11","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"908","name":"국방일보","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/908.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/908.png"},"showThumbnailView":true,"showListView":true,"regDate":"20240116 17:16:57","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"909","name":"기호일보","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/909.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/909.png"},"showThumbnailView":true,"showListView":true,"regDate":"20240116 21:20:04","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"353","name":"중앙SUNDAY","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/353.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/353.png"},"showThumbnailView":true,"showListView":true,"regDate":"20240117 08:31:35","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"354","name":"엘르","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/354.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/354.png"},"showThumbnailView":true,"showListView":true,"regDate":"20240117 09:00:00","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"355","name":"사이언스타임즈","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/355.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/355.png"},"showThumbnailView":true,"showListView":true,"regDate":"20240116 14:36:21","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"356","name":"게임메카","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/356.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/356.png"},"showThumbnailView":true,"showListView":true,"regDate":"20240116 18:21:43","_id":null,"@type":"PC-NEWS ...
# window["EAGER-DATA"]["PC-NEWSSTAND-YONHAP"] = {"@type":"BLOCK","blocks":[{"@type":"BLOCK","blocks":null,"materials":[],"excludeInPaging":false,"positionForPaging":0,"realtime":false,"_id":null,"@type":"BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null}],"materials":[{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"'직접 면담' 최선희 환대한 푸틴, 북한 답방시계 빨리 돌아가나","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0014449086","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"643543b2caf3d87b7e0a0da6"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"이재명, 피습 15일만에 당무 복귀…\"국민 맡긴 책임, 최선다해 수행\"","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0014448993","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"65692532e9bedeca62543dbb"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"내일까지 전국에 가끔 비·눈…주말까지 포근","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0014448917","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"65692532e9bedeca62543dbc"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"고교생 4명 중 1명은 \"우리 반 친구들, 수업시간에 자요\"","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0014448830","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"65692532e9bedeca62543dbd"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"육아휴직 불이익 여전…기업 절반 \"휴직한 만큼 승진 늦어져\"","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0014448744","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"65692532e9bedeca62543dbe"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"지역 등지는 청년…강원·충청 대졸자 10명 중 6명, 수도권 취업","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0014448721","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"65692532e9bedeca62543dbf"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"공식 수입도 안됐는데…작년 中 전기승용차 美 제치고 수입 2위","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0014448720","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"65692532e9bedeca62543dc0"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"'건보료 0원' 피부양자 2천만명선→1천600만명대로 감소","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0014448715","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"6573c24ecaf3d87b7e4d5269"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"일본맥주 수입 5년 만에 1위 탈환…'방뇨' 중국맥주 3위로","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0014448714","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"65a2ab3683266959d97c94d3"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"현역 입대 피하려 지적장애 진단까지…아이돌 멤버 집 ...
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-SEARCH-RIGHT"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[{"content":{"imageDark":"https://s.pstatic.net/static/www/mobile/edit/20240108_1095/upload_1704701260518p6pDo.png","image":"https://s.pstatic.net/static/www/mobile/edit/20240108_1095/upload_1704701256033PnhCQ.png","url":"https://chzzk.naver.com/","alt":"치지직"},"exposure":true,"@miniContentId":"659bad5a94eec44065226b83","@miniContentCode":"PC-SEARCH-RIGHT","@startAt":"2024-01-08 00:00","@endAt":"2024-02-08 23:59","@createdAt":"2024-01-08T17:07:54.715","@updatedAt":"2024-01-08T17:07:54.715"},{"content":{"imageDark":"https://s.pstatic.net/static/www/mobile/edit/20240108_1095/upload_1704701318156pt3FO.png","image":"https://s.pstatic.net/static/www/mobile/edit/20240108_1095/upload_17047013121634Q4Cs.png","url":"https://chzzk.naver.com/","alt":"치지직"},"exposure":true,"@miniContentId":"659bad873b6eb61b8bd23dbd","@miniContentCode":"PC-SEARCH-RIGHT","@startAt":"2024-01-08 00:00","@endAt":"2024-02-08 23:59","@createdAt":"2024-01-08T17:08:39.619","@updatedAt":"2024-01-08T17:08:39.619"}],"_id":"6433d8a5a10d300685012682","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-SEARCH-RIGHT","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"d344940d-b4d3-11ee-9284-fd803b397336","@provider":"lambda","@lastModifiedAt":[2024,1,17,1,0,37,98000000]}
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-MEDIA-TAB-EVENT"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[{"content":{"altText":"2023 카타르 아시안컵","darkImage":"https://s.pstatic.net/static/www/mobile/edit/20240110_1095/upload_1704851435106c5RLq.png","lightImage":"https://s.pstatic.net/static/www/mobile/edit/20240110_1095/upload_17048514254674MZPF.png","url":"https://sports.news.naver.com/kfootball/index"},"exposure":true,"@miniContentId":"659df805616d6b26850941d8","@miniContentCode":"PC-MEDIA-TAB-EVENT","@startAt":"2024-01-11 12:00","@endAt":"2024-02-13 23:59","@createdAt":"2024-01-10T10:51:01.674","@updatedAt":"2024-01-11T12:34:50.554"}],"_id":"643687e1a10d300685630556","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-MEDIA-TAB-EVENT","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"da6bc946-b4d3-11ee-ac5f-cd74b218a1e3","@provider":"lambda","@lastModifiedAt":[2024,1,17,1,0,49,110000000]}
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-MID-BANNER"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[],"_id":"648ae476a10d300685fbab10","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-MID-BANNER","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"cfb32fe3-b4d3-11ee-9284-c98d6d1f8a07","@provider":"lambda","@lastModifiedAt":[2024,1,17,1,0,31,117000000]}
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-TAB-META"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[{"content":{"area":"FEED","tabList":[{"clickCode":"tct.mynr","name":"추천・구독","id":"PC-FEED-RECOMMEND","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"tct.wtn","name":"자동차","id":"PC-FEED-CARGAME","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.wtn","name":"웹툰","id":"PC-FEED-WEBTOON","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.bty","name":"패션뷰티","id":"PC-FEED-BEAUTY","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"tct.fod","name":"레시피","id":"PC-FEED-RECIPE","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.lif","name":"리빙","id":"PC-FEED-LIVINGHOME","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.bok","name":"책방","id":"PC-FEED-CULTURE","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.lec","name":"지식+","id":"PC-FEED-LECTURE","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.health","name":"건강","id":"PC-FEED-HEALTH","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"tct.gameapp","name":"게임","id":"PC-FEED-GAMEAPP","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1}],"@type":"BLOCK-PC-TAB-META"},"exposure":true,"@miniContentId":"643e64d370a065058f369bac","@miniContentCode":"PC-TAB-META","@startAt":"2023-04-10 00:00","@endAt":"2030-05-30 23:59","@createdAt":"2023-04-18T18:37:23.412","@updatedAt":"2023-11-08T11:34:03.902"},{"content":{"area":"MEDIA","tabList":[{"clickCode":"nst.nsd","name":"뉴스스탠드","id":"PC-MEDIA-NEWSSTAND","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.nch","name":"언론사편집","id":"PC-MEDIA-NEWS","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.ent","name":"엔터","id":"PC-MEDIA-ENTER","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.spo","name":"스포츠","id":"PC-MEDIA-SPORTS","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.fin","name":"경제","id":"PC-MEDIA-ECONOMIC","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1}],"@type":"BLOCK-PC-TAB-META"},"exposure":true,"@miniContentId":"643e642c8793487c84743a38","@miniContentCode":"PC-TAB-META","@startAt":"2023-04-11 00:00","@endAt":"2030-05-31 23:59","@createdAt":"2023-04-18T18:34:36.648","@updatedAt":"2023-04-18T18:34:36.648"}],"_id":"643e6299a10d3006853cc04c","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-TAB-META","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"b91a9428-b4d3-11ee-9284-a5268f0f0e4b","@provider":"lambda","@lastModifiedAt":[2024,1,17,0,59,53,210000000]}
# </script> <script defer="defer" src="https://pm.pstatic.net/resources/js/polyfill.37930f2b.js?o=www" crossorigin="anonymous"></script><script defer="defer" src="https://pm.pstatic.net/resources/js/preload.8c808364.js?o=www" crossorigin="anonymous"></script><script defer="defer" src="https://pm.pstatic.net/resources/js/search.e6d3b50c.js?o=www" crossorigin="anonymous"></script><script defer="defer" src="https://pm.pstatic.net/resources/js/main.2aaf9522.js?o=www" crossorigin="anonymous"></script><link href="https://pm.pstatic.net/resources/css/main.71860705.css" rel="stylesheet"></head> <body> <div id="u_skip"> <a href="#topAsideButton"><span>상단영역 바로가기</span></a> <a href="#shortcutArea"><span>서비스 메뉴 바로가기</span></a> <a href="#newsstand"><span>새소식 블록 바로가기</span></a> <a href="#shopping"><span>쇼핑 블록 바로가기</span></a> <a href="#feed"><span>관심사 블록 바로가기</span></a> <a href="#account"><span>MY 영역 바로가기</span></a> <a href="#widgetboard"><span>위젯 보드 바로가기</span></a> <a href="#viewSetting"><span>보기 설정 바로가기</span></a> </div>   <script type="text/plain" id="ad-timeboard-response" data-gfp-banner-size="830x130" data-gfp-banner-type="full">{"payload":{"requestId":"0afe959e46f74219a753f73b196fd4b8","head":{"version":"0.0.1","description":"Naver SSP Waterfall List"},"eventTracking":{"ackImpressions":[{"url":"https://tivan.naver.com/sc2/1/"}],"activeViewImpressions":[{"url":"https://tivan.naver.com/sc2/2/"}],"clicks":[{"url":"https://tivan.naver.com/sc2/3/"}],"completions":[{"url":"https://tivan.naver.com/sc2/4/"}],"attached":[{"url":"https://tivan.naver.com/sc2/10/"}],"renderedImpressions":[{"url":"https://tivan.naver.com/sc2/11/"}],"viewableImpressions":[{"url":"https://tivan.naver.com/sc2/12/"}],"loadErrors":[{"url":"https://tivan.naver.com/sc2/91/"}],"startErrors":[{"url":"https://tivan.naver.com/sc2/92/"}],"mute":[{"url":"https://tivan.naver.com/sc2/5/"}],"close":[{"url":"https://tivan.naver.com/sc2/6/"}]},"adUnit":"p_main_timeboard_v1","randomNumber":66,"adDivId":"ad_timeboard","advertiserDomains":["go.sdu.ac.kr"],"adDuplicationKeys":["URL:http://go.sdu.ac.kr"],"ads":[{"encrypted":"tTzAu3qReExca2Ju_3diTvHTsa85hkvj23RmcQ8o8WmGlzIfxOntBRVnzhJhG46Xc87-JeAgL8QB_3LIkVk-zPhMSqX3PFeNlZDe7OdsYUKA6IkrctueGsF5aV9lLJ5EDnPIemj9Z1duz3LDOMZbJjC0hg3kGJBS-oMOosRR2az06W0csQRFbDN1K3pBDC2tziSe5FeT2PQFot3TnXXB4KBLUF8JVMFF5Y-An-yNdzlLvoOENyt_nGZZuWN_2f-caYwMB_-MOqDJCGOnHeAtUahhcvSO2z18WYE67AlSbXfyWgpQ02ySNe-nonRhOevsD9JB8-sEsbPqwp86VhDwk8XE8aY-AFSWuv05jMKveC9nDe6DO6B_54MoY0E6-zVqZMHFJIIauIfIl1eF5Wg0aPpRq7ZPY8s9x5-CyNEIdi94Usz_-pTnEkePheNpI5HSMhhPE9Q0FjJnygAL4rwoKFWFfwUxZPO0cFBCvwb5ibc6WGqckBwl_TLuzzDQ7sCTiCwUha1TDyuN6GgveNH_szBg0KLIiGo83NqbmtWrk76SQZcYnCysmL5Ie59xYvORjaQ1hcO_Gg1jEx_SQVxJccmWzzalw5d2ov7qUzYXhLOYv6Ib4kkLz9N8p8o4ZpHaTyYhVf-vBqbKpdAGrUNFMzeykV6_T6P6i9yky0R7UU7nlfCBCC1DAbdEehqeGLwzfYK5YrUD6v7H71AMEtJzuucu1s5T0-so6tWoZdWdhxl21aUW3mMCUaPRBalvHCLj","connectionType":"S2S","adProviderType":"IN_NAVER","adProviderName":"NDP_SF","layoutType":"FLUID","creativeType":"BANNER","renderType":"SF","eventTracking":{"ackImpressions":[{"url":"https://siape.veta.naver.com/openrtb/nurl?eu=EU10043565\u0026calp=-\u0026oj=cQgn6aire5PrVAf8fEP%2FGOXUUsIZpgT7gl1xVC%2BNlzNOY0sr8bj%2Fb4xOHiXtVrUwJL1qM2Pf%2FakD64B4m8qIUPzq%2BXCI4fuV6EtCNW2%2BPQXIBWexIpibH0plqdgUSG%2BUXrQSw%2B%2FX1bbNCF9%2F110BZDp0hCNKO%2BcHo2M9jEOAPSLbaIdXv9YIFqKzdZWOwZvbdMAtSn%2B9Id4vH4MuGzFJiErLLp1Ox71Vg1K%2FFXnNMQA\u0026ac=8907929\u0026src=6902983\u0026evtcd=BID_WIN\u0026x_ti=1506\u0026rk=jTiLvZyFy526XGxrTkFpZg\u0026eltts=cNDTMCQ0p3ID7SFgVf8hsA%3D%3D\u0026brs=Y\u0026"}],"attached":[],"activeViewImpressions":[],"renderedImpressions":[],"viewableImpressions":[],"clicks":[],"vimp1px":[],"vimp100":[],"vimp100p":[],"admute":[],"advmute":[],"like":[],"unlike":[],"close":[],"bounce":[]},"adInfo":{"placeId":"6436232db28a76002ea3f30c","adomain":["go.sdu.ac.kr"],"cid":"1473263","crid":"2591292","exp":3545,"adm":"%3Cscript%20src%3D%22https%3A%2F%2Fssl.pstatic.net%2Fmelona%2Flibs%2Fglad%2Fbridge%2Fgfp-bridge.js%22%3E%3C%2Fsc ...
# </script> <div id="wrap"> <div id="header" role="banner"> <div id="topSearchWrap" class="header_inner"> <div id="special-logo" class="search_special_bg"></div> <div id="timeboard-ex" class="ad_area" style="min-width:1340px"> </div> <div id="search_area" class="search_area" style="border-color:#fff"> <div id="special-input-logo-ex" class="link_search_special" style="display:none"></div> <div class="search_group"> <div id="search" class="search_group_inner"> <h1 id="special-input-logo" class="search_logo"></h1> <form id="sform" name="search" role="search" action="https://search.naver.com/search.naver" method="get"> <fieldset> <legend class="blind">검색</legend> <input type="hidden" name="where" value="nexearch"/> <input type="hidden" id="sm" name="sm" value="top_hty"/> <input type="hidden" id="fbm" name="fbm" value="0"/> <input type="hidden" id="acr" name="acr" value="" disabled="disabled"/> <input type="hidden" id="acq" name="acq" value="" disabled="disabled"/> <input type="hidden" id="qdt" name="qdt" value="" disabled="disabled"/> <input type="hidden" id="ie" name="ie" value="utf8"/> <input type="hidden" id="acir" name="acir" value="" disabled="disabled"/> <input type="hidden" id="os" name="os" value="" disabled="disabled"/> <input type="hidden" id="bid" name="bid" value="" disabled="disabled"/> <input type="hidden" id="pkid" name="pkid" value="" disabled="disabled"/> <input type="hidden" id="eid" name="eid" value="" disabled="disabled"/> <input type="hidden" id="mra" name="mra" value="" disabled="disabled"/> <div class="search_input_box"> <input id="query" name="query" type="search" title="검색어를 입력해 주세요." placeholder="검색어를 입력해 주세요." maxlength="255" autocomplete="off" class="search_input" data-atcmp-element/> </div> <button type="submit" class="btn_search" onclick='window.nclk_v2(this,"sch.action")'> <span class="ico_btn_search_svg"> <svg id="search-btn" viewBox="0 0 50 50" xmlns="http://www.w3.org/2000/svg"> <path d="M22.13.5c11.378 0 20.632 9.256 20.632 20.63 0 4.699-1.566 9.155-4.439 12.782l10.164 10.165a2.41 2.41 0 0 1-1.706 4.115 2.412 2.412 0 0 1-1.706-.705L33.31 35.719a2.41 2.41 0 0 1 0-3.41 15.71 15.71 0 0 0 4.628-11.178c0-8.718-7.09-15.808-15.807-15.808-8.718 0-15.808 7.09-15.808 15.808 0 7.15 4.817 13.43 11.714 15.273a2.41 2.41 0 0 1 1.705 2.954 2.41 2.41 0 0 1-2.95 1.705C7.788 38.658 1.5 30.46 1.5 21.131 1.5 9.756 10.756.5 22.13.5zm4.716 34.746a3.483 3.483 0 1 1 0 6.966 3.483 3.483 0 0 1 0-6.966z"/> </svg> </span> <span class="blind">검색</span> </button> </fieldset> </form> <div class="search_box"> <button id="ke_kbd_btn" type="button" class="btn_keyboard" aria-pressed="false"> <span class="keybord_text"> <span class="blind">입력도구</span> </span> </button> <div id="_nx_kbd" style="display:none"></div> <button id="nautocomplete" type="button" class="btn_arrow" data-atcmp-element> <span class="blind">자동완성/최근검색어펼치기</span> </button> </div> <div class="layer_atcmp" id="autoFrame" style="display:none"> <div class="ly_atcmp" data-atcmp-element> <div class="api_atcmp_wrap"> <div class="atcmp_fixer _recent_layer" style="display:none"> <div class="atcmp_header _recent_header"> <strong class="tit">최근 검색어</strong> <div class="option"> <a role="button" href="#" class="item _delAll" aria-pressed="false">전체삭제</a> </div> </div> <div class="atcmp_container"> <ul class="kwd_lst _recent"></ul> <div class="kwd_info kwd_off _offMsg" style="display:none">검색어 저장 기능이 꺼져 있습니다.<br/><span class="kwd_dsc">설정이 초기화 된다면 <a href="https://help.naver.com/alias/search/word/word_35.naver" class="kwd_help" data-clk="sly.help" target="_blank">도움말</a>을 확인해주세요.</span></div> <div class="kwd_info kwd_none _recentNone" style="display:none">최근 검색어 내역이 없습니다.<br/><span class="kwd_dsc">설정이 초기화 된다면 <a href="https://help.naver.com/alias/search/word/word_35.naver" class="kwd_help" data-clk="sly.help" target="_blank">도움말</a>을 확인해주세요.</span></div> </div> <div class="atcmp_footer"> <span class="side_opt_area"> <span class="opt_item"> <a href="#" class="close _keywordOnOff"> ...
#         window['EAGER-DATA']['GV'] = {
#             svt: '20240117100053',  }; </script> <script>!function(){function t(t){var e=document.getElementById("search_area"),n=document.getElementById("search-btn");if(!t)return e&&e.removeAttribute("style"),void(n&&n.setAttribute("style","fill: #03c75a"));e&&e.setAttribute("style","border-color: "+t),n&&n.setAttribute("class","ico_btn_search type_color"),n&&n.setAttribute("style","fill: "+t)}var e=window["EAGER-DATA"]["CAS-MINICONTENT-PC-SPECIAL-LOGO"];if(!e||!e.items||e.items.length>0==!1)return void t();var n=Math.floor(Math.random()*e.items.length),i=e.items[n];e.items=[i],t(i&&i.content&&i.content.input&&i.content.input.color);const l=document.getElementById("search");l&&l.classList.add("type_special_logo_full"),window.addEventListener("header-sticky-state-change",(()=>{var t;(t=document.getElementById("header"))&&t.classList.contains("ani_fixed")?l&&l.classList.remove("type_special_logo_full"):l&&l.classList.add("type_special_logo_full")}));var s=i&&i.content&&i.content.input&&i.content.input.placeholder;if(s){var o=document.getElementById("query");o&&s&&o.setAttribute("title",s),o&&s&&o.setAttribute("placeholder",s)}}()</script> </body> </html>

# %%
url = f"https://open.assembly.go.kr/portal/openapi/{data_id}?KEY={YOUR_API_KEY}&AGE=21&Type=json"
response = requests.get(url).json()

# %%
response
# Out:
# {'nzmimeepazxkubdpn': [{'head': [{'list_total_count': 23381},
#     {'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다.'}}]},
#   {'row': [{'BILL_ID': 'PRC_M2V4T0T1S1Y5X0W9V4E5B0A6J0I1H0',
#      'BILL_NO': '2126297',
#      'BILL_NAME': '마약류 관리에 관한 법률 일부개정법률안',
#      'COMMITTEE': None,
#      'PROPOSE_DT': '2024-01-16',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_M2V4T0T1S1Y5X0W9V4E5B0A6J0I1H0&ageFrom=21&ageTo=21',
#      'PROPOSER': '한정애의원 등 10인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_M2V4T0T1S1Y5X0W9V4E5B0A6J0I1H0',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': None,
#      'PROC_DT': None,
#      'COMMITTEE_ID': None,
#      'PUBL_PROPOSER': '윤미향,이원욱,김민석,김홍걸,강훈식,정성호,이성만,최인호,박홍근',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '한정애'},
#     {'BILL_ID': 'PRC_Y2Y4X0X1F1G1E0C9D3B5C4Y4Y2X1V2',
#      'BILL_NO': '2126296',
#      'BILL_NAME': '국고금 관리법 일부개정법률안',
#      'COMMITTEE': None,
#      'PROPOSE_DT': '2024-01-16',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_Y2Y4X0X1F1G1E0C9D3B5C4Y4Y2X1V2&ageFrom=21&ageTo=21',
#      'PROPOSER': '김상훈의원 등 10인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_Y2Y4X0X1F1G1E0C9D3B5C4Y4Y2X1V2',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': None,
#      'PROC_DT': None,
#      'COMMITTEE_ID': None,
#      'PUBL_PROPOSER': '조수진,김희곤,정희용,이종성,엄태영,김도읍,김형동,박대수,권영세',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '김상훈'},
#     {'BILL_ID': 'PRC_C2C4B0B1A1A1Z1H0H3F0G4E5F3D4E8',
#      'BILL_NO': '2126295',
#      'BILL_NAME': '국가과학기술자문회의법 일부개정법률안',
#      'COMMITTEE': None,
#      'PROPOSE_DT': '2024-01-16',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_C2C4B0B1A1A1Z1H0H3F0G4E5F3D4E8&ageFrom=21&ageTo=21',
#      'PROPOSER': '김도읍의원 등 12인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_C2C4B0B1A1A1Z1H0H3F0G4E5F3D4E8',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': None,
#      'PROC_DT': None,
#      'COMMITTEE_ID': None,
#      'PUBL_PROPOSER': '유경준,권명호,김석기,윤한홍,김병욱,김미애,권성동,지성호,박형수,유상범,장동혁',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '김도읍'},
#     {'BILL_ID': 'PRC_X2Y4X0V1V1U1U1C0D2B9Z3A9Y3Z1H0',
#      'BILL_NO': '2126294',
#      'BILL_NAME': '교원의 지위 향상 및 교육활동 보호를 위한 특별법 일부개정법률안',
#      'COMMITTEE': None,
#      'PROPOSE_DT': '2024-01-16',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_X2Y4X0V1V1U1U1C0D2B9Z3A9Y3Z1H0&ageFrom=21&ageTo=21',
#      'PROPOSER': '김도읍의원 등 11인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_X2Y4X0V1V1U1U1C0D2B9Z3A9Y3Z1H0',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': None,
#      'PROC_DT': None,
#      'COMMITTEE_ID': None,
#      'PUBL_PROPOSER': '유경준,권명호,김석기,윤한홍,김병욱,권성동,지성호,박형수,유상범,장동혁',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '김도읍'},
#     {'BILL_ID': 'PRC_L2L4J0K1G1E0E1D0E0C2C2K6J4J3I0',
#      'BILL_NO': '2126293',
#      'BILL_NAME': '연구개발특구의 육성에 관한 특별법 일부개정법률안',
#      'COMMITTEE': None,
#      'PROPOSE_DT': '2024-01-16',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_L2L4J0K1G1E0E1D0E0C2C2K6J4J3I0&ageFrom=21&ageTo=21',
#      'PROPOSER': '박성중의원 등 11인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_L2L4J0K1G1E0E1D0E0C2C2K6J4J3I0',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': None,
#      'PROC_DT': None,
#      'COMMITTEE_ID': None,
#      'PUBL_PROPOSER': '유경준,최춘식,이종성,양향자,김영식,태영호,황보승희,전봉민,김은희,이주환',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '박성중'},
#     {'BILL_ID': 'PRC_G2F4F0E1L1M0L1L0J0I3I0Q7R8P8Q6',
#      'BILL_NO': '2126292',
#      'BILL_NAME': '전파법 일부개정법률안',
#      'COMMITTEE': None,
#      'PROPOSE_DT': '2024-01-16',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_G2F4F0E1L1M0L1L0J0I3I0Q7R8P8Q6&ageFrom=21&ageTo=21',
#      'PROPOSER': '박성중의원 등 11인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_G2F4F0E1L1M0L1L0J0I3I0Q7R8P8Q6',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': None,
#      'PROC_DT': None,
#      'COMMITTEE_ID': None,
#      'PUBL_PROPOSER': '최춘식,유경준,이종성,양향자,김영식,태영호,황보승희,전봉민,김은희,이주환',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '박성중'},
#     {'BILL_ID': 'PRC_U2U4T0U1S1S0R1Z0Z0Y0Y3X2X3V7W3',
#      'BILL_NO': '2126291',
#      'BILL_NAME': '전기통신사업법 일부개정법률안',
#      'COMMITTEE': None,
#      'PROPOSE_DT': '2024-01-16',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_U2U4T0U1S1S0R1Z0Z0Y0Y3X2X3V7W3&ageFrom=21&ageTo=21',
#      'PROPOSER': '박성중의원 등 11인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_U2U4T0U1S1S0R1Z0Z0Y0Y3X2X3V7W3',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': None,
#      'PROC_DT': None,
#      'COMMITTEE_ID': None,
#      'PUBL_PROPOSER': '유경준,최춘식,이종성,양향자,김영식,태영호,황보승희,전봉민,김은희,이주환',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '박성중'},
#     {'BILL_ID': 'PRC_B2Z4Z0I1I1G1H1F0E3E1M1N8L3K0K1',
#      'BILL_NO': '2126290',
#      'BILL_NAME': '적합성평가 관리 등에 관한 법률 일부개정법률안',
#      'COMMITTEE': None,
#      'PROPOSE_DT': '2024-01-16',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_B2Z4Z0I1I1G1H1F0E3E1M1N8L3K0K1&ageFrom=21&ageTo=21',
#      'PROPOSER': '김도읍의원 등 11인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_B2Z4Z0I1I1G1H1F0E3E1M1N8L3K0K1',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': None,
#      'PROC_DT': None,
#      'COMMITTEE_ID': None,
#      'PUBL_PROPOSER': '유경준,권명호,김석기,윤한홍,김병욱,김미애,권성동,지성호,장동혁,박형수',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '김도읍'},
#     {'BILL_ID': 'PRC_Y2W4V0W1U1U1D1D0C3A1A4Y6A4H3I5',
#      'BILL_NO': '2126289',
#      'BILL_NAME': '채무자 회생 및 파산에 관한 법률 일부개정법률안',
#      'COMMITTEE': None,
#      'PROPOSE_DT': '2024-01-16',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_Y2W4V0W1U1U1D1D0C3A1A4Y6A4H3I5&ageFrom=21&ageTo=21',
#      'PROPOSER': '김도읍의원 등 11인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_Y2W4V0W1U1U1D1D0C3A1A4Y6A4H3I5',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': None,
#      'PROC_DT': None,
#      'COMMITTEE_ID': None,
#      'PUBL_PROPOSER': '유경준,권명호,김석기,윤한홍,김병욱,권성동,지성호,박형수,유상범,장동혁',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '김도읍'},
#     {'BILL_ID': 'PRC_T2T4S0Q1R1P1Q1M0K2K8J5K0I0I0R2',
#      'BILL_NO': '2126288',
#      'BILL_NAME': '개인정보 보호법 일부개정법률안',
#      'COMMITTEE': None,
#      'PROPOSE_DT': '2024-01-16',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_T2T4S0Q1R1P1Q1M0K2K8J5K0I0I0R2&ageFrom=21&ageTo=21',
#      'PROPOSER': '김도읍의원 등 11인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_T2T4S0Q1R1P1Q1M0K2K8J5K0I0I0R2',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': None,
#      'PROC_DT': None,
#      'COMMITTEE_ID': None,
#      'PUBL_PROPOSER': '유경준,권명호,김석기,윤한홍,김병욱,김미애,권성동,지성호,장동혁,박형수',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '김도읍'},
#     {'BILL_ID': 'PRC_V2U4U0S1O0P8N0N9M4N5L3T6U5S0T2',
#      'BILL_NO': '2126287',
#      'BILL_NAME': '집합건물의 소유 및 관리에 관한 법률 일부개정법률안',
#      'COMMITTEE': '법제사법위원회',
#      'PROPOSE_DT': '2024-01-15',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_V2U4U0S1O0P8N0N9M4N5L3T6U5S0T2&ageFrom=21&ageTo=21',
#      'PROPOSER': '정일영의원 등 16인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_V2U4U0S1O0P8N0N9M4N5L3T6U5S0T2',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-16',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700006',
#      'PUBL_PROPOSER': '이동주,이성만,김두관,김교흥,김병기,신동근,정성호,김주영,장경태,기동민,허숙정,홍정민,전혜숙,강민정,김상희',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '정일영'},
#     {'BILL_ID': 'PRC_G2F4F0E1E1U0V1T4R4S4Q4R1Z8Z1Y4',
#      'BILL_NO': '2126286',
#      'BILL_NAME': '공공기관의 정보공개에 관한 법률 일부개정법률안',
#      'COMMITTEE': '행정안전위원회',
#      'PROPOSE_DT': '2024-01-15',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_G2F4F0E1E1U0V1T4R4S4Q4R1Z8Z1Y4&ageFrom=21&ageTo=21',
#      'PROPOSER': '박성민의원 등 10인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_G2F4F0E1E1U0V1T4R4S4Q4R1Z8Z1Y4',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-16',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700480',
#      'PUBL_PROPOSER': '김용판,이헌승,김병욱,이용,전봉민,이명수,이달곤,이종성,김성원',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '박성민'},
#     {'BILL_ID': 'PRC_Z2A4Y0Y1G1H1F0E9E4C9E2L2M3K7J2',
#      'BILL_NO': '2126285',
#      'BILL_NAME': '제재처분 기준 정비 등을 위한 간척지의 농어업적 이용 및 관리에 관한 법률 등 6개 법률의 일부개정에 관한 법률안',
#      'COMMITTEE': '농림축산식품해양수산위원회',
#      'PROPOSE_DT': '2024-01-12',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_Z2A4Y0Y1G1H1F0E9E4C9E2L2M3K7J2&ageFrom=21&ageTo=21',
#      'PROPOSER': '이달곤의원 등 13인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_Z2A4Y0Y1G1H1F0E9E4C9E2L2M3K7J2',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-15',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700408',
#      'PUBL_PROPOSER': '황보승희,강기윤,박덕흠,최형두,홍문표,김영선,최춘식,박성민,권성동,백종헌,윤한홍,정희용',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '이달곤'},
#     {'BILL_ID': 'PRC_I2G4G0E1G1E1E0M9L5L2K1K0I8E6F5',
#      'BILL_NO': '2126284',
#      'BILL_NAME': '제재처분 기준 정비 등을 위한 수산식품산업의 육성 및 지원에 관한 법률 등 8개 법률의 일부개정에 관한 법률안',
#      'COMMITTEE': '농림축산식품해양수산위원회',
#      'PROPOSE_DT': '2024-01-12',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_I2G4G0E1G1E1E0M9L5L2K1K0I8E6F5&ageFrom=21&ageTo=21',
#      'PROPOSER': '이달곤의원 등 13인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_I2G4G0E1G1E1E0M9L5L2K1K0I8E6F5',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-15',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700408',
#      'PUBL_PROPOSER': '황보승희,강기윤,박덕흠,최형두,홍문표,김영선,최춘식,박성민,권성동,윤한홍,백종헌,정희용',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '이달곤'},
#     {'BILL_ID': 'PRC_U2A4Z0Z1Y1G2D1C3K2J1I2H5D7A6Z3',
#      'BILL_NO': '2126283',
#      'BILL_NAME': '건설산업기본법 일부개정법률안',
#      'COMMITTEE': '국토교통위원회',
#      'PROPOSE_DT': '2024-01-12',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_U2A4Z0Z1Y1G2D1C3K2J1I2H5D7A6Z3&ageFrom=21&ageTo=21',
#      'PROPOSER': '김성원의원 등 10인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_U2A4Z0Z1Y1G2D1C3K2J1I2H5D7A6Z3',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-15',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700407',
#      'PUBL_PROPOSER': '이헌승,하영제,한무경,김승수,박대수,최영희,이인선,김용판,이종성',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '김성원'},
#     {'BILL_ID': 'PRC_S2S4Q0E1C1C2A1J4I1G3G5O7L0J0S6',
#      'BILL_NO': '2126282',
#      'BILL_NAME': '금융혁신지원 특별법 일부개정법률안',
#      'COMMITTEE': '정무위원회',
#      'PROPOSE_DT': '2024-01-12',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_S2S4Q0E1C1C2A1J4I1G3G5O7L0J0S6&ageFrom=21&ageTo=21',
#      'PROPOSER': '송석준의원 등 12인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_S2S4Q0E1C1C2A1J4I1G3G5O7L0J0S6',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-15',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700008',
#      'PUBL_PROPOSER': '유상범,김예지,이헌승,전주혜,이종배,박덕흠,김형동,김성원,윤창현,김상훈,김학용',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '송석준'},
#     {'BILL_ID': 'PRC_Z2Y4X0W1C1B2A1X0W4L0K0J9D1C3B3',
#      'BILL_NO': '2126281',
#      'BILL_NAME': '집회 및 시위에 관한 법률 일부개정법률안',
#      'COMMITTEE': '행정안전위원회',
#      'PROPOSE_DT': '2024-01-12',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_Z2Y4X0W1C1B2A1X0W4L0K0J9D1C3B3&ageFrom=21&ageTo=21',
#      'PROPOSER': '김용판의원 등 15인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_Z2Y4X0W1C1B2A1X0W4L0K0J9D1C3B3',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-15',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700480',
#      'PUBL_PROPOSER': '박성민,하영제,김병욱,백종헌,김영식,박대수,전봉민,임이자,이주환,최춘식,권명호,박덕흠,김성원,강대식',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '김용판'},
#     {'BILL_ID': 'PRC_E2T4S0N1L1K2T1Q0O3Y3U3R8A6Z0V3',
#      'BILL_NO': '2126280',
#      'BILL_NAME': '노인복지법 일부개정법률안',
#      'COMMITTEE': '보건복지위원회',
#      'PROPOSE_DT': '2024-01-12',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_E2T4S0N1L1K2T1Q0O3Y3U3R8A6Z0V3&ageFrom=21&ageTo=21',
#      'PROPOSER': '김용판의원 등 15인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_E2T4S0N1L1K2T1Q0O3Y3U3R8A6Z0V3',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-15',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700341',
#      'PUBL_PROPOSER': '박성민,하영제,김병욱,백종헌,김영식,박대수,전봉민,이주환,임이자,최춘식,권명호,박덕흠,김성원,강대식',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '김용판'},
#     {'BILL_ID': 'PRC_E2D4X0X1K1Y2X1W0D3C9B1J8G5F9D5',
#      'BILL_NO': '2126279',
#      'BILL_NAME': '옥외광고물 등의 관리와 옥외광고산업 진흥에 관한 법률 일부개정법률안',
#      'COMMITTEE': '행정안전위원회',
#      'PROPOSE_DT': '2024-01-12',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_E2D4X0X1K1Y2X1W0D3C9B1J8G5F9D5&ageFrom=21&ageTo=21',
#      'PROPOSER': '김용판의원 등 15인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_E2D4X0X1K1Y2X1W0D3C9B1J8G5F9D5',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-15',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700480',
#      'PUBL_PROPOSER': '박성민,하영제,김병욱,백종헌,김영식,박대수,전봉민,이주환,임이자,최춘식,권명호,박덕흠,김성원,강대식',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '김용판'},
#     {'BILL_ID': 'PRC_D2J4I0H1O1N2M1V0R3P7O4X3U7T4B8',
#      'BILL_NO': '2126278',
#      'BILL_NAME': '다중이용업소의 안전관리에 관한 특별법 일부개정법률안',
#      'COMMITTEE': '행정안전위원회',
#      'PROPOSE_DT': '2024-01-12',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_D2J4I0H1O1N2M1V0R3P7O4X3U7T4B8&ageFrom=21&ageTo=21',
#      'PROPOSER': '김용판의원 등 15인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_D2J4I0H1O1N2M1V0R3P7O4X3U7T4B8',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-15',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700480',
#      'PUBL_PROPOSER': '박성민,하영제,김병욱,백종헌,김영식,박대수,전봉민,이주환,임이자,최춘식,권명호,박덕흠,김성원,강대식',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '김용판'},
#     {'BILL_ID': 'PRC_W2V4D0A1Z1I2H1G0H4E1D1M1K6J2J7',
#      'BILL_NO': '2126277',
#      'BILL_NAME': '국민 안전교육 진흥 기본법 일부개정법률안',
#      'COMMITTEE': '행정안전위원회',
#      'PROPOSE_DT': '2024-01-12',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_W2V4D0A1Z1I2H1G0H4E1D1M1K6J2J7&ageFrom=21&ageTo=21',
#      'PROPOSER': '김용판의원 등 15인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_W2V4D0A1Z1I2H1G0H4E1D1M1K6J2J7',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-15',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700480',
#      'PUBL_PROPOSER': '박성민,하영제,김병욱,백종헌,김영식,박대수,전봉민,이주환,임이자,권명호,최춘식,박덕흠,김성원,강대식',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '김용판'},
#     {'BILL_ID': 'PRC_G2F4M0M1S1R2R1Z3W4U6E1D2Z4Z5F6',
#      'BILL_NO': '2126275',
#      'BILL_NAME': '공직선거법 일부개정법률안',
#      'COMMITTEE': '행정안전위원회',
#      'PROPOSE_DT': '2024-01-12',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_G2F4M0M1S1R2R1Z3W4U6E1D2Z4Z5F6&ageFrom=21&ageTo=21',
#      'PROPOSER': '김용판의원 등 14인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_G2F4M0M1S1R2R1Z3W4U6E1D2Z4Z5F6',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-15',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700480',
#      'PUBL_PROPOSER': '하영제,백종헌,김영식,박대수,전봉민,박성민,임이자,이주환,최춘식,권명호,박덕흠,김성원,강대식',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '김용판'},
#     {'BILL_ID': 'PRC_Q2Q4Y0Z1X0X9W1U4V2R6R4Q9O4P6N3',
#      'BILL_NO': '2126274',
#      'BILL_NAME': '국민의 형사재판 참여에 관한 법률 일부개정법률안',
#      'COMMITTEE': '법제사법위원회',
#      'PROPOSE_DT': '2024-01-12',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_Q2Q4Y0Z1X0X9W1U4V2R6R4Q9O4P6N3&ageFrom=21&ageTo=21',
#      'PROPOSER': '전주혜의원 등 11인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_Q2Q4Y0Z1X0X9W1U4V2R6R4Q9O4P6N3',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-15',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700006',
#      'PUBL_PROPOSER': '우신구,유상범,조수진,유경준,윤주경,이명수,홍문표,이태규,정경희,박대수',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '전주혜'},
#     {'BILL_ID': 'PRC_O2M4U0V1T0T9S1S4R2Z4A1Y2Y7W2V4',
#      'BILL_NO': '2126273',
#      'BILL_NAME': '형사소송법 일부개정법률안',
#      'COMMITTEE': '법제사법위원회',
#      'PROPOSE_DT': '2024-01-12',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_O2M4U0V1T0T9S1S4R2Z4A1Y2Y7W2V4&ageFrom=21&ageTo=21',
#      'PROPOSER': '전주혜의원 등 14인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_O2M4U0V1T0T9S1S4R2Z4A1Y2Y7W2V4',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-15',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700006',
#      'PUBL_PROPOSER': '우신구,김예지,유상범,조수진,유경준,윤창현,윤주경,이명수,홍문표,이태규,정경희,박대수,정희용',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '전주혜'},
#     {'BILL_ID': 'PRC_R2P4O0O1W0W5V1W1U3U1T1B2B3A2A7',
#      'BILL_NO': '2126272',
#      'BILL_NAME': '응급의료에 관한 법률 일부개정법률안',
#      'COMMITTEE': '보건복지위원회',
#      'PROPOSE_DT': '2024-01-12',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_R2P4O0O1W0W5V1W1U3U1T1B2B3A2A7&ageFrom=21&ageTo=21',
#      'PROPOSER': '이주환의원 등 11인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_R2P4O0O1W0W5V1W1U3U1T1B2B3A2A7',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-15',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700341',
#      'PUBL_PROPOSER': '김학용,백종헌,권명호,안병길,박대수,정동만,김성원,김용판,이헌승,전봉민',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '이주환'},
#     {'BILL_ID': 'PRC_Z2Y4W0X1V0W9E1C3C2B0C0A5I2J9H6',
#      'BILL_NO': '2126271',
#      'BILL_NAME': '경기도와 서울특별시 간 관할구역 변경에 관한 특별법안',
#      'COMMITTEE': '행정안전위원회',
#      'PROPOSE_DT': '2024-01-12',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_Z2Y4W0X1V0W9E1C3C2B0C0A5I2J9H6&ageFrom=21&ageTo=21',
#      'PROPOSER': '이용의원 등 10인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_Z2Y4W0X1V0W9E1C3C2B0C0A5I2J9H6',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-15',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700480',
#      'PUBL_PROPOSER': '윤창현,박대수,조은희,지성호,김승수,구자근,김예지,박성민,홍문표',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '이용'},
#     {'BILL_ID': 'PRC_G2H3P1P2N2M6N1L6M0T7U0T2R6R3P0',
#      'BILL_NO': '2126270',
#      'BILL_NAME': '독점규제 및 공정거래에 관한 법률 일부개정법률안',
#      'COMMITTEE': '정무위원회',
#      'PROPOSE_DT': '2024-01-12',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_G2H3P1P2N2M6N1L6M0T7U0T2R6R3P0&ageFrom=21&ageTo=21',
#      'PROPOSER': '김희곤의원 등 11인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_G2H3P1P2N2M6N1L6M0T7U0T2R6R3P0',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-15',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700008',
#      'PUBL_PROPOSER': '최춘식,태영호,김용판,하영제,박정하,이명수,정운천,지성호,박성민,백종헌',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '김희곤'},
#     {'BILL_ID': 'PRC_O2S4Y0J1Y1R2S0B9E1P1Z4Q7R0S0U8',
#      'BILL_NO': '2126269',
#      'BILL_NAME': '동물보호법 일부개정법률안',
#      'COMMITTEE': '농림축산식품해양수산위원회',
#      'PROPOSE_DT': '2024-01-12',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_O2S4Y0J1Y1R2S0B9E1P1Z4Q7R0S0U8&ageFrom=21&ageTo=21',
#      'PROPOSER': '박홍근의원ㆍ이헌승의원ㆍ심상정의원 등 18인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_O2S4Y0J1Y1R2S0B9E1P1Z4Q7R0S0U8',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-15',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700408',
#      'PUBL_PROPOSER': '김상희,김민석,우원식,윤미향,진성준,한정애,조오섭,박성민,이주환,최춘식,박덕흠,하영제,정경희,서영석,이동주',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '박홍근,이헌승,심상정'},
#     {'BILL_ID': 'PRC_W2Y4P0V1O1B2W0W9P0G7F5G9O0D5Q3',
#      'BILL_NO': '2126268',
#      'BILL_NAME': '남해안권 관광산업 발전 특별법안',
#      'COMMITTEE': '문화체육관광위원회',
#      'PROPOSE_DT': '2024-01-12',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_W2Y4P0V1O1B2W0W9P0G7F5G9O0D5Q3&ageFrom=21&ageTo=21',
#      'PROPOSER': '서삼석의원ㆍ양향자의원ㆍ최형두의원 등 11인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_W2Y4P0V1O1B2W0W9P0G7F5G9O0D5Q3',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-15',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700513',
#      'PUBL_PROPOSER': '이달곤,윤한홍,김예지,김성원,강기윤,김태호,한무경,정동만',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '서삼석,양향자,최형두'},
#     {'BILL_ID': 'PRC_Z2Z3Y0W8W2F9F1D6C4C4B5B8J1K6I8',
#      'BILL_NO': '2126267',
#      'BILL_NAME': '인구감소지역 지원 특별법 일부개정법률안',
#      'COMMITTEE': '행정안전위원회',
#      'PROPOSE_DT': '2024-01-11',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_Z2Z3Y0W8W2F9F1D6C4C4B5B8J1K6I8&ageFrom=21&ageTo=21',
#      'PROPOSER': '서삼석의원 등 10인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_Z2Z3Y0W8W2F9F1D6C4C4B5B8J1K6I8',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-12',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700480',
#      'PUBL_PROPOSER': '양정숙,홍정민,송갑석,이상헌,오영환,이개호,조오섭,김승남,신정훈',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '서삼석'},
#     {'BILL_ID': 'PRC_Z2X4Y0X1X0T2R2S0Q5R3P2Q6Y9W2X9',
#      'BILL_NO': '2126266',
#      'BILL_NAME': '해운법 일부개정법률안',
#      'COMMITTEE': '농림축산식품해양수산위원회',
#      'PROPOSE_DT': '2024-01-11',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_Z2X4Y0X1X0T2R2S0Q5R3P2Q6Y9W2X9&ageFrom=21&ageTo=21',
#      'PROPOSER': '서삼석의원 등 10인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_Z2X4Y0X1X0T2R2S0Q5R3P2Q6Y9W2X9',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-12',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700408',
#      'PUBL_PROPOSER': '양정숙,허숙정,홍정민,홍성국,오영환,안호영,한병도,김승남,소병훈',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '서삼석'},
#     {'BILL_ID': 'PRC_R2Y3Z0X8Y2W9X1V6D4D4C0D6B6Z3A7',
#      'BILL_NO': '2126265',
#      'BILL_NAME': '출입국관리법 일부개정법률안',
#      'COMMITTEE': '법제사법위원회',
#      'PROPOSE_DT': '2024-01-11',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_R2Y3Z0X8Y2W9X1V6D4D4C0D6B6Z3A7&ageFrom=21&ageTo=21',
#      'PROPOSER': '서삼석의원등10인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_R2Y3Z0X8Y2W9X1V6D4D4C0D6B6Z3A7',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-12',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700006',
#      'PUBL_PROPOSER': '김승남,송갑석,신정훈,신현영,양정숙,오영환,윤영덕,이개호,진성준',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '서삼석'},
#     {'BILL_ID': 'PRC_R2Q3R0P3O1W5V1V3D3E2D3B1A3I7G1',
#      'BILL_NO': '2126264',
#      'BILL_NAME': '영유아보육법 일부개정법률안',
#      'COMMITTEE': '보건복지위원회',
#      'PROPOSE_DT': '2024-01-11',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_R2Q3R0P3O1W5V1V3D3E2D3B1A3I7G1&ageFrom=21&ageTo=21',
#      'PROPOSER': '서삼석의원 등 12인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_R2Q3R0P3O1W5V1V3D3E2D3B1A3I7G1',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-12',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700341',
#      'PUBL_PROPOSER': '김승남,서동용,소병훈,어기구,이개호,이상헌,임호선,장경태,조오섭,주철현,허종식',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '서삼석'},
#     {'BILL_ID': 'PRC_Q2Q3Z0Z9X1W7X1V5W2D2E3D6B0B3A6',
#      'BILL_NO': '2126263',
#      'BILL_NAME': '해양환경관리법 일부개정법률안',
#      'COMMITTEE': '농림축산식품해양수산위원회',
#      'PROPOSE_DT': '2024-01-11',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_Q2Q3Z0Z9X1W7X1V5W2D2E3D6B0B3A6&ageFrom=21&ageTo=21',
#      'PROPOSER': '서삼석의원 등 13인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_Q2Q3Z0Z9X1W7X1V5W2D2E3D6B0B3A6',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-12',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700408',
#      'PUBL_PROPOSER': '김승남,김정호,소병훈,신정훈,양정숙,오영환,위성곤,윤재갑,이개호,이용선,진성준,한병도',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '서삼석'},
#     {'BILL_ID': 'PRC_U2V4T0T1S0T9R0R9N2M3M4K4L1J0K9',
#      'BILL_NO': '2126262',
#      'BILL_NAME': '국가첨단전략산업 경쟁력 강화 및 보호에 관한 특별조치법 일부개정법률안',
#      'COMMITTEE': '산업통상자원중소벤처기업위원회',
#      'PROPOSE_DT': '2024-01-11',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_U2V4T0T1S0T9R0R9N2M3M4K4L1J0K9&ageFrom=21&ageTo=21',
#      'PROPOSER': '최혜영의원 등 12인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_U2V4T0T1S0T9R0R9N2M3M4K4L1J0K9',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-12',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700481',
#      'PUBL_PROPOSER': '강민정,권인숙,권칠승,김상희,오영환,유정주,이탄희,전용기,정춘숙,홍기원,홍성국',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '최혜영'},
#     {'BILL_ID': 'PRC_B2C3K1K2I2H6I1G6H0W8X2W9U7U8T0',
#      'BILL_NO': '2126261',
#      'BILL_NAME': '독점규제 및 공정거래에 관한 법률 일부개정법률안',
#      'COMMITTEE': '정무위원회',
#      'PROPOSE_DT': '2024-01-11',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_B2C3K1K2I2H6I1G6H0W8X2W9U7U8T0&ageFrom=21&ageTo=21',
#      'PROPOSER': '김희곤의원 등 11인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_B2C3K1K2I2H6I1G6H0W8X2W9U7U8T0',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-12',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700008',
#      'PUBL_PROPOSER': '김용판,박성민,박정하,백종헌,이명수,정운천,지성호,최춘식,태영호,하영제',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '김희곤'},
#     {'BILL_ID': 'PRC_L2K3L1J2J2F9D1E0D0D3B0J0K1I1J5',
#      'BILL_NO': '2126260',
#      'BILL_NAME': '핵심에너지 수급관리 및 수송위기 대응 등에 관한 법률안',
#      'COMMITTEE': '산업통상자원중소벤처기업위원회',
#      'PROPOSE_DT': '2024-01-11',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_L2K3L1J2J2F9D1E0D0D3B0J0K1I1J5&ageFrom=21&ageTo=21',
#      'PROPOSER': '최형두의원 등 10인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_L2K3L1J2J2F9D1E0D0D3B0J0K1I1J5',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-12',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700481',
#      'PUBL_PROPOSER': '강기윤,김성원,김예지,김희곤,어기구,위성곤,이성만,최인호,황보승희',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '최형두'},
#     {'BILL_ID': 'PRC_D2Z3A1Y2Z1X9W1W4E2F1D0E8C4B0B5',
#      'BILL_NO': '2126259',
#      'BILL_NAME': '지역공공은행 설립에 관한 특별법안',
#      'COMMITTEE': '행정안전위원회',
#      'PROPOSE_DT': '2024-01-11',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_D2Z3A1Y2Z1X9W1W4E2F1D0E8C4B0B5&ageFrom=21&ageTo=21',
#      'PROPOSER': '배진교의원 등 10인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_D2Z3A1Y2Z1X9W1W4E2F1D0E8C4B0B5',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-12',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700480',
#      'PUBL_PROPOSER': '강성희,강은미,민병덕,박찬대,심상정,이동주,이은주,장혜영,허종식',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '배진교'},
#     {'BILL_ID': 'PRC_G2H3G0E5E1M2N1L5M2K7J2J2Y1Z0X0',
#      'BILL_NO': '2126258',
#      'BILL_NAME': '정당법 일부개정법률안',
#      'COMMITTEE': '행정안전위원회',
#      'PROPOSE_DT': '2024-01-11',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_G2H3G0E5E1M2N1L5M2K7J2J2Y1Z0X0&ageFrom=21&ageTo=21',
#      'PROPOSER': '최형두의원 등 12인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_G2H3G0E5E1M2N1L5M2K7J2J2Y1Z0X0',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-12',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700480',
#      'PUBL_PROPOSER': '강기윤,구자근,권명호,김성원,김예지,박수영,서일준,안병길,엄태영,임이자,지성호',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '최형두'},
#     {'BILL_ID': 'PRC_M2M3I0J5H1I2G1H5F2F6O3M2M2K3L2',
#      'BILL_NO': '2126257',
#      'BILL_NAME': '공직선거법 일부개정법률안',
#      'COMMITTEE': '행정안전위원회',
#      'PROPOSE_DT': '2024-01-11',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_M2M3I0J5H1I2G1H5F2F6O3M2M2K3L2&ageFrom=21&ageTo=21',
#      'PROPOSER': '최형두의원 등 11인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_M2M3I0J5H1I2G1H5F2F6O3M2M2K3L2',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-12',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700480',
#      'PUBL_PROPOSER': '강기윤,구자근,김성원,김예지,박수영,서일준,안병길,엄태영,임이자,지성호',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '최형두'},
#     {'BILL_ID': 'PRC_R2Q4Q0M1M0L8J1K7I3J7R5P4Q8O1P2',
#      'BILL_NO': '2126256',
#      'BILL_NAME': '선박의 입항 및 출항 등에 관한 법률 일부개정법률안',
#      'COMMITTEE': '농림축산식품해양수산위원회',
#      'PROPOSE_DT': '2024-01-11',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_R2Q4Q0M1M0L8J1K7I3J7R5P4Q8O1P2&ageFrom=21&ageTo=21',
#      'PROPOSER': '윤주경의원 등 15인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_R2Q4Q0M1M0L8J1K7I3J7R5P4Q8O1P2',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-12',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700408',
#      'PUBL_PROPOSER': '강대식,권명호,김용판,김희곤,박대수,백종헌,서병수,송석준,유경준,윤창현,이용호,이인선,장동혁,전주혜',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '윤주경'},
#     {'BILL_ID': 'PRC_U2U4T0R1S1A0B1Z5Z4Y7W3X6F6F2D9',
#      'BILL_NO': '2126255',
#      'BILL_NAME': '제재처분 기준 정비 등을 위한 고압가스 안전관리법 등 5개 법률의 일부개정에 관한 법률안',
#      'COMMITTEE': '산업통상자원중소벤처기업위원회',
#      'PROPOSE_DT': '2024-01-10',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_U2U4T0R1S1A0B1Z5Z4Y7W3X6F6F2D9&ageFrom=21&ageTo=21',
#      'PROPOSER': '김성원의원 등 10인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_U2U4T0R1S1A0B1Z5Z4Y7W3X6F6F2D9',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-11',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700481',
#      'PUBL_PROPOSER': '김용판,류성걸,박대수,양금희,이인선,이종성,정운천,최영희,태영호',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '김성원'},
#     {'BILL_ID': 'PRC_U2S4T0R1Z1A0Y1Z5X1X1W0E0E1D6E6',
#      'BILL_NO': '2126254',
#      'BILL_NAME': '소상공인 생계형 적합업종 지정에 관한 특별법 일부개정법률안',
#      'COMMITTEE': '산업통상자원중소벤처기업위원회',
#      'PROPOSE_DT': '2024-01-10',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_U2S4T0R1Z1A0Y1Z5X1X1W0E0E1D6E6&ageFrom=21&ageTo=21',
#      'PROPOSER': '김성원의원 등 10인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_U2S4T0R1Z1A0Y1Z5X1X1W0E0E1D6E6',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-11',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700481',
#      'PUBL_PROPOSER': '김용판,류성걸,박대수,양금희,이인선,이종성,정운천,최영희,태영호',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '김성원'},
#     {'BILL_ID': 'PRC_K2G3G1F2D1D3C1D6K5J7J0I7I4H9H0',
#      'BILL_NO': '2126253',
#      'BILL_NAME': '수산업협동조합법 일부개정법률안',
#      'COMMITTEE': '농림축산식품해양수산위원회',
#      'PROPOSE_DT': '2024-01-10',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_K2G3G1F2D1D3C1D6K5J7J0I7I4H9H0&ageFrom=21&ageTo=21',
#      'PROPOSER': '박찬대의원 등 10인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_K2G3G1F2D1D3C1D6K5J7J0I7I4H9H0',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-11',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700408',
#      'PUBL_PROPOSER': '문진석,이정문,박성준,장경태,유기홍,전재수,허종식,조승래,이인영',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '박찬대'},
#     {'BILL_ID': 'PRC_X2F4E0E1C1D0C1C1Y2W0X4V0W7U4V7',
#      'BILL_NO': '2126252',
#      'BILL_NAME': '행정상 강제 규정 정비를 위한 마약류 관리에 관한 법률 등 6개 법률의 일부개정에 관한 법률안',
#      'COMMITTEE': '보건복지위원회',
#      'PROPOSE_DT': '2024-01-10',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_X2F4E0E1C1D0C1C1Y2W0X4V0W7U4V7&ageFrom=21&ageTo=21',
#      'PROPOSER': '강기윤의원 등 10인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_X2F4E0E1C1D0C1C1Y2W0X4V0W7U4V7',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-11',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700341',
#      'PUBL_PROPOSER': '유상범,김미애,백종헌,유의동,최연숙,이종성,최형두,최영희,서정숙',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '강기윤'},
#     {'BILL_ID': 'PRC_D2B4J0K1I1J0H1I1G2O1P3N4O4M4N2',
#      'BILL_NO': '2126251',
#      'BILL_NAME': '제재처분 기준 정비 등을 위한 노인복지법 등 7개 법률의 일부개정에 관한 법률안',
#      'COMMITTEE': '보건복지위원회',
#      'PROPOSE_DT': '2024-01-10',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_D2B4J0K1I1J0H1I1G2O1P3N4O4M4N2&ageFrom=21&ageTo=21',
#      'PROPOSER': '강기윤의원 등 10인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_D2B4J0K1I1J0H1I1G2O1P3N4O4M4N2',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-11',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700341',
#      'PUBL_PROPOSER': '유상범,김미애,백종헌,유의동,최연숙,이종성,최형두,최영희,서정숙',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '강기윤'},
#     {'BILL_ID': 'PRC_C2A4B0A1A0Y9G1H1G2G1E5F2D3Z3A5',
#      'BILL_NO': '2126250',
#      'BILL_NAME': '생명공학육성법 일부개정법률안',
#      'COMMITTEE': '과학기술정보방송통신위원회',
#      'PROPOSE_DT': '2024-01-10',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_C2A4B0A1A0Y9G1H1G2G1E5F2D3Z3A5&ageFrom=21&ageTo=21',
#      'PROPOSER': '박대출의원 등 11인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_C2A4B0A1A0Y9G1H1G2G1E5F2D3Z3A5',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-11',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700479',
#      'PUBL_PROPOSER': '김병욱,김예지,김태호,김형동,류성걸,박성민,서범수,이명수,이용,지성호',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '박대출'},
#     {'BILL_ID': 'PRC_G2E3F1N2L2M7K1L4J4K4R3S3R4P6P9',
#      'BILL_NO': '2126249',
#      'BILL_NAME': '형사소송법 일부개정법률안',
#      'COMMITTEE': '법제사법위원회',
#      'PROPOSE_DT': '2024-01-10',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_G2E3F1N2L2M7K1L4J4K4R3S3R4P6P9&ageFrom=21&ageTo=21',
#      'PROPOSER': '김남국의원 등 10인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_G2E3F1N2L2M7K1L4J4K4R3S3R4P6P9',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-11',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700006',
#      'PUBL_PROPOSER': '강득구,강민정,김승원,민형배,박성준,양이원영,양정숙,윤영덕,이성만',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '김남국'},
#     {'BILL_ID': 'PRC_R2P4P0O1W0W9V1V2U5S0T3A6B2A8A9',
#      'BILL_NO': '2126248',
#      'BILL_NAME': '공직선거법 일부개정법률안',
#      'COMMITTEE': '행정안전위원회',
#      'PROPOSE_DT': '2024-01-10',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_R2P4P0O1W0W9V1V2U5S0T3A6B2A8A9&ageFrom=21&ageTo=21',
#      'PROPOSER': '이병훈의원 등 18인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_R2P4P0O1W0W9V1V2U5S0T3A6B2A8A9',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-11',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700480',
#      'PUBL_PROPOSER': '김철민,김회재,민형배,박정,송갑석,윤영덕,이개호,이장섭,이형석,전재수,전혜숙,조오섭,주철현,한정애,한준호,허영,홍성국',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '이병훈'},
#     {'BILL_ID': 'PRC_R2R4N0O1M0N4L1J7K0S6S5R8R4Q6O6',
#      'BILL_NO': '2126247',
#      'BILL_NAME': '지방자치법 일부개정법률안',
#      'COMMITTEE': '행정안전위원회',
#      'PROPOSE_DT': '2024-01-10',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_R2R4N0O1M0N4L1J7K0S6S5R8R4Q6O6&ageFrom=21&ageTo=21',
#      'PROPOSER': '노웅래의원 등 12인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_R2R4N0O1M0N4L1J7K0S6S5R8R4Q6O6',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-11',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700480',
#      'PUBL_PROPOSER': '김경협,김병기,김영진,김철민,양기대,윤후덕,이학영,전혜숙,최인호,한병도,허숙정',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '노웅래'},
#     {'BILL_ID': 'PRC_B2J3H1I2G0H6F1G6B5A9A0Y2A6Y6Y7',
#      'BILL_NO': '2126246',
#      'BILL_NAME': '국유재산특례제한법 일부개정법률안',
#      'COMMITTEE': '기획재정위원회',
#      'PROPOSE_DT': '2024-01-09',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_B2J3H1I2G0H6F1G6B5A9A0Y2A6Y6Y7&ageFrom=21&ageTo=21',
#      'PROPOSER': '주호영의원 등 10인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_B2J3H1I2G0H6F1G6B5A9A0Y2A6Y6Y7',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-10',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700300',
#      'PUBL_PROPOSER': '권영세,김도읍,김용판,김형동,김희곤,윤상현,이용,이헌승,장동혁',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '주호영'},
#     {'BILL_ID': 'PRC_O2N3L1L2K0L1G0H9F0E0E3C2D7L6L8',
#      'BILL_NO': '2126245',
#      'BILL_NAME': '범죄피해자 보호법 일부개정법률안',
#      'COMMITTEE': '법제사법위원회',
#      'PROPOSE_DT': '2024-01-09',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_O2N3L1L2K0L1G0H9F0E0E3C2D7L6L8&ageFrom=21&ageTo=21',
#      'PROPOSER': '전주혜의원 등 10인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_O2N3L1L2K0L1G0H9F0E0E3C2D7L6L8',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-10',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700006',
#      'PUBL_PROPOSER': '우신구,유경준,유상범,윤창현,이명수,이태규,정경희,조수진,주호영',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '전주혜'},
#     {'BILL_ID': 'PRC_C2Y3Z1X2X1W1U1V6D5D0C3A5B8Z5A1',
#      'BILL_NO': '2126244',
#      'BILL_NAME': '지방세특례제한법 일부개정법률안',
#      'COMMITTEE': '행정안전위원회',
#      'PROPOSE_DT': '2024-01-09',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_C2Y3Z1X2X1W1U1V6D5D0C3A5B8Z5A1&ageFrom=21&ageTo=21',
#      'PROPOSER': '천준호의원 등 10인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_C2Y3Z1X2X1W1U1V6D5D0C3A5B8Z5A1',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-10',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700480',
#      'PUBL_PROPOSER': '강병원,강은미,강훈식,남인순,민병덕,용혜인,이은주,장혜영,정태호',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '천준호'},
# ...
#      'PROPOSER': '전봉민의원 등 10인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_P2K3J1J2I2J9H0H9Q4O3O4N7N4L4M9',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-02',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700512',
#      'PUBL_PROPOSER': '김병욱,김용판,박성민,박성중,안병길,이종성,이헌승,정동만,정운천',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '전봉민'},
#     {'BILL_ID': 'PRC_Q2O3P1X2X2W9W0V9T4U0P3Q8O0P1N7',
#      'BILL_NO': '2126147',
#      'BILL_NAME': '국립대학병원 설치법 일부개정법률안',
#      'COMMITTEE': '교육위원회',
#      'PROPOSE_DT': '2023-12-29',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_Q2O3P1X2X2W9W0V9T4U0P3Q8O0P1N7&ageFrom=21&ageTo=21',
#      'PROPOSER': '전봉민의원 등 10인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_Q2O3P1X2X2W9W0V9T4U0P3Q8O0P1N7',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-02',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700512',
#      'PUBL_PROPOSER': '김병욱,김용판,박성민,박성중,안병길,이종성,이헌승,정동만,정운천',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '전봉민'},
#     {'BILL_ID': 'PRC_Z2A3H1J2H2H9G0E9F4A8B4Z2A3Y1X6',
#      'BILL_NO': '2126146',
#      'BILL_NAME': '지방의료원의 설립 및 운영에 관한 법률 일부개정법률안',
#      'COMMITTEE': '보건복지위원회',
#      'PROPOSE_DT': '2023-12-29',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_Z2A3H1J2H2H9G0E9F4A8B4Z2A3Y1X6&ageFrom=21&ageTo=21',
#      'PROPOSER': '전봉민의원 등 10인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_Z2A3H1J2H2H9G0E9F4A8B4Z2A3Y1X6',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-02',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700341',
#      'PUBL_PROPOSER': '김병욱,김용판,박성민,박성중,안병길,이종성,이헌승,정동만,정운천',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '전봉민'},
#     {'BILL_ID': 'PRC_B2K3I1H1G1O4P1N3V1U2T4U8S1A5Y5',
#      'BILL_NO': '2126145',
#      'BILL_NAME': '지역공공은행 설립 및 운영에 관한 특별법안',
#      'COMMITTEE': '행정안전위원회',
#      'PROPOSE_DT': '2023-12-29',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_B2K3I1H1G1O4P1N3V1U2T4U8S1A5Y5&ageFrom=21&ageTo=21',
#      'PROPOSER': '강성희의원 등 12인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_B2K3I1H1G1O4P1N3V1U2T4U8S1A5Y5',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-04',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700480',
#      'PUBL_PROPOSER': '고민정,민병덕,배진교,심상정,양정숙,용혜인,윤미향,윤영덕,이동주,장혜영,허숙정',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '강성희'},
#     {'BILL_ID': 'PRC_W2U3V1T2U2S9A0B9Z4Z8Y0Z4X5T3T0',
#      'BILL_NO': '2126144',
#      'BILL_NAME': '서울대학교치과병원 설치법 일부개정법률안',
#      'COMMITTEE': '교육위원회',
#      'PROPOSE_DT': '2023-12-29',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_W2U3V1T2U2S9A0B9Z4Z8Y0Z4X5T3T0&ageFrom=21&ageTo=21',
#      'PROPOSER': '전봉민의원 등 11인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_W2U3V1T2U2S9A0B9Z4Z8Y0Z4X5T3T0',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-02',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700512',
#      'PUBL_PROPOSER': '김병욱,김용판,박성민,박성중,안병길,이종성,이주환,이헌승,정동만,정운천',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '전봉민'},
#     {'BILL_ID': 'PRC_P2N3O1N2N2V9V0U9S4T5R4S4H2H3G3',
#      'BILL_NO': '2126143',
#      'BILL_NAME': '국립중앙의료원의 설립 및 운영에 관한 법률 일부개정법률안',
#      'COMMITTEE': '보건복지위원회',
#      'PROPOSE_DT': '2023-12-29',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_P2N3O1N2N2V9V0U9S4T5R4S4H2H3G3&ageFrom=21&ageTo=21',
#      'PROPOSER': '전봉민의원 등 10인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_P2N3O1N2N2V9V0U9S4T5R4S4H2H3G3',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-02',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700341',
#      'PUBL_PROPOSER': '김병욱,김용판,박성민,박성중,안병길,이종성,이헌승,정동만,정운천',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '전봉민'},
#     {'BILL_ID': 'PRC_H2I3G1H2F1G3B1A0A3Y4A1Y6Y2G0F3',
#      'BILL_NO': '2126142',
#      'BILL_NAME': '감염병의 예방 및 관리에 관한 법률 일부개정법률안',
#      'COMMITTEE': '보건복지위원회',
#      'PROPOSE_DT': '2023-12-29',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_H2I3G1H2F1G3B1A0A3Y4A1Y6Y2G0F3&ageFrom=21&ageTo=21',
#      'PROPOSER': '강기윤의원 등 10인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_H2I3G1H2F1G3B1A0A3Y4A1Y6Y2G0F3',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-02',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700341',
#      'PUBL_PROPOSER': '김미애,김상훈,박덕흠,백종헌,유의동,이용호,이종성,임병헌,조명희',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '강기윤'},
#     {'BILL_ID': 'PRC_L2K3L1J2I2I7Q1R1P1P7O2M9N1U4W6',
#      'BILL_NO': '2126141',
#      'BILL_NAME': '최저임금법 일부개정법률안',
#      'COMMITTEE': '환경노동위원회',
#      'PROPOSE_DT': '2023-12-29',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_L2K3L1J2I2I7Q1R1P1P7O2M9N1U4W6&ageFrom=21&ageTo=21',
#      'PROPOSER': '윤미향의원 등 11인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_L2K3L1J2I2I7Q1R1P1P7O2M9N1U4W6',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-02',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700038',
#      'PUBL_PROPOSER': '강민정,강성희,강은미,김의겸,김종민,송옥주,윤영찬,전용기,허영,홍기원',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '윤미향'},
#     {'BILL_ID': 'PRC_X2Y3X1S2T2R7Q1R1P1Q2X3Y4W1V4V2',
#      'BILL_NO': '2126140',
#      'BILL_NAME': '기간제 및 단시간근로자 보호 등에 관한 법률 일부개정법률안',
#      'COMMITTEE': '환경노동위원회',
#      'PROPOSE_DT': '2023-12-29',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_X2Y3X1S2T2R7Q1R1P1Q2X3Y4W1V4V2&ageFrom=21&ageTo=21',
#      'PROPOSER': '윤미향의원 등 11인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_X2Y3X1S2T2R7Q1R1P1Q2X3Y4W1V4V2',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-02',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700038',
#      'PUBL_PROPOSER': '강민정,강성희,강은미,김의겸,김종민,송옥주,윤영찬,전용기,허영,홍기원',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '윤미향'},
#     {'BILL_ID': 'PRC_Q2Q3P1Q2O2N7N1V1W0U9U4T8R1S6N1',
#      'BILL_NO': '2126139',
#      'BILL_NAME': '가사근로자의 고용개선 등에 관한 법률 일부개정법률안',
#      'COMMITTEE': '환경노동위원회',
#      'PROPOSE_DT': '2023-12-29',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_Q2Q3P1Q2O2N7N1V1W0U9U4T8R1S6N1&ageFrom=21&ageTo=21',
#      'PROPOSER': '윤미향의원 등 11인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_Q2Q3P1Q2O2N7N1V1W0U9U4T8R1S6N1',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-02',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700038',
#      'PUBL_PROPOSER': '강민정,강성희,강은미,김의겸,김종민,송옥주,윤영찬,전용기,허영,홍기원',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '윤미향'},
#     {'BILL_ID': 'PRC_X2V3V1E2C2C8B0C9A5A4I2H6H6F0G9',
#      'BILL_NO': '2126138',
#      'BILL_NAME': '공휴일에 관한 법률 일부개정법률안',
#      'COMMITTEE': '행정안전위원회',
#      'PROPOSE_DT': '2023-12-29',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_X2V3V1E2C2C8B0C9A5A4I2H6H6F0G9&ageFrom=21&ageTo=21',
#      'PROPOSER': '유경준의원 등 10인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_X2V3V1E2C2C8B0C9A5A4I2H6H6F0G9',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-02',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700480',
#      'PUBL_PROPOSER': '강대식,김예지,김학용,노용호,엄태영,이용,정동만,정우택,태영호',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '유경준'},
#     {'BILL_ID': 'PRC_D2L3M1K2K2J7K1I1I0Q8P5P1N9O1N9',
#      'BILL_NO': '2126137',
#      'BILL_NAME': '근로기준법 일부개정법률안',
#      'COMMITTEE': '환경노동위원회',
#      'PROPOSE_DT': '2023-12-29',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_D2L3M1K2K2J7K1I1I0Q8P5P1N9O1N9&ageFrom=21&ageTo=21',
#      'PROPOSER': '윤미향의원 등 11인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_D2L3M1K2K2J7K1I1I0Q8P5P1N9O1N9',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-02',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700038',
#      'PUBL_PROPOSER': '강민정,강성희,강은미,김의겸,김종민,송옥주,윤영찬,전용기,허영,홍기원',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '윤미향'},
#     {'BILL_ID': 'PRC_E2M3L1M2L2R0S1R6P5O4K4J6J8I9G5',
#      'BILL_NO': '2126136',
#      'BILL_NAME': '위치정보의 보호 및 이용 등에 관한 법률 전부개정법률안',
#      'COMMITTEE': '과학기술정보방송통신위원회',
#      'PROPOSE_DT': '2023-12-29',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_E2M3L1M2L2R0S1R6P5O4K4J6J8I9G5&ageFrom=21&ageTo=21',
#      'PROPOSER': '홍석준의원 등 10인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_E2M3L1M2L2R0S1R6P5O4K4J6J8I9G5',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-02',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700479',
#      'PUBL_PROPOSER': '김영식,김용판,박덕흠,박성중,이주환,조경태,지성호,최영희,하영제',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '홍석준'},
#     {'BILL_ID': 'PRC_A2A3Z1V2V1U4U1T7T4S1A0A9Y7Z7X9',
#      'BILL_NO': '2126135',
#      'BILL_NAME': '화물자동차 운수사업법 일부개정법률안',
#      'COMMITTEE': '국토교통위원회',
#      'PROPOSE_DT': '2023-12-29',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_A2A3Z1V2V1U4U1T7T4S1A0A9Y7Z7X9&ageFrom=21&ageTo=21',
#      'PROPOSER': '김정재의원 등 10인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_A2A3Z1V2V1U4U1T7T4S1A0A9Y7Z7X9',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-02',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700407',
#      'PUBL_PROPOSER': '김용판,이종배,권명호,박정하,김학용,박덕흠,김성원,이종성,박대수',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '김정재'},
#     {'BILL_ID': 'PRC_P2O3M1N2U0V6U1U1S2T5R1Z7A8Y2Z8',
#      'BILL_NO': '2126134',
#      'BILL_NAME': '군용비행장·군사격장 소음 방지 및 피해 보상에 관한 법률 일부개정법률안',
#      'COMMITTEE': '국방위원회',
#      'PROPOSE_DT': '2023-12-29',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_P2O3M1N2U0V6U1U1S2T5R1Z7A8Y2Z8&ageFrom=21&ageTo=21',
#      'PROPOSER': '변재일의원 등 13인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_P2O3M1N2U0V6U1U1S2T5R1Z7A8Y2Z8',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-02',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700019',
#      'PUBL_PROPOSER': '강준현,고용진,민병덕,민형배,양향자,유동수,윤미향,윤영찬,윤후덕,인재근,전용기,허영',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '변재일'},
#     {'BILL_ID': 'PRC_W2W3V1T2U2S7T1A1Z2A7Y3Z2X5X2G5',
#      'BILL_NO': '2126133',
#      'BILL_NAME': '공유재산 및 물품 관리법 일부개정법률안',
#      'COMMITTEE': '행정안전위원회',
#      'PROPOSE_DT': '2023-12-29',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_W2W3V1T2U2S7T1A1Z2A7Y3Z2X5X2G5&ageFrom=21&ageTo=21',
#      'PROPOSER': '민병덕의원 등 18인 외 1인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_W2W3V1T2U2S7T1A1Z2A7Y3Z2X5X2G5',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-02',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700480',
#      'PUBL_PROPOSER': '강득구,강훈식,김성주,김성환,김종민,김한규,서영교,송기헌,안규백,오영환,윤영덕,이동주,이성만,이학영,최종윤,허숙정,황운하',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '민병덕'},
#     {'BILL_ID': 'PRC_I2W3T0T2P0M1L1T0T0P2X4V7U7U8A3',
#      'BILL_NO': '2126132',
#      'BILL_NAME': '형사소송법 일부개정법률안',
#      'COMMITTEE': '법제사법위원회',
#      'PROPOSE_DT': '2023-12-29',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_I2W3T0T2P0M1L1T0T0P2X4V7U7U8A3&ageFrom=21&ageTo=21',
#      'PROPOSER': '김승원의원 등 18인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_I2W3T0T2P0M1L1T0T0P2X4V7U7U8A3',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-02',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700006',
#      'PUBL_PROPOSER': '권인숙,김경협,김정호,민병덕,민형배,서영교,서영석,신정훈,양이원영,이재정,이형석,임오경,임종성,정필모,조오섭,주철현,홍익표',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '김승원'},
#     {'BILL_ID': 'PRC_G2G3O1O2N2L1M1K5L5T8T5S3Q0R7P7',
#      'BILL_NO': '2126131',
#      'BILL_NAME': '동물보호법 일부개정법률안',
#      'COMMITTEE': '농림축산식품해양수산위원회',
#      'PROPOSE_DT': '2023-12-29',
#      'PROC_RESULT': None,
#      'AGE': '21',
#      'DETAIL_LINK': 'http://likms.assembly.go.kr/bill/billDetail.do?billId=PRC_G2G3O1O2N2L1M1K5L5T8T5S3Q0R7P7&ageFrom=21&ageTo=21',
#      'PROPOSER': '윤미향의원 등 10인',
#      'MEMBER_LIST': 'http://likms.assembly.go.kr/bill/coactorListPopup.do?billId=PRC_G2G3O1O2N2L1M1K5L5T8T5S3Q0R7P7',
#      'LAW_PROC_DT': None,
#      'LAW_PRESENT_DT': None,
#      'LAW_SUBMIT_DT': None,
#      'CMT_PROC_RESULT_CD': None,
#      'CMT_PROC_DT': None,
#      'CMT_PRESENT_DT': None,
#      'COMMITTEE_DT': '2024-01-02',
#      'PROC_DT': None,
#      'COMMITTEE_ID': '9700408',
#      'PUBL_PROPOSER': '강성희,김성주,김의겸,박홍근,신현영,위성곤,윤재갑,전용기,황운하',
#      'LAW_PROC_RESULT_CD': None,
#      'RST_PROPOSER': '윤미향'}]}]}

# %%
# 한 번에 100개씩 밖에 데이터를 못가져 온다...
len(response[data_id][1]['row'])
# Out:
# 100

# %%
max_page = response[data_id][0]['head'][0]['list_total_count']
max_page
# Out:
# 23381

# %%
all_laws = []
for page_num in range(1, int(max_page/1000+2)):
    p_size= page_num*1000
    p_index = page_num
    url = f"https://open.assembly.go.kr/portal/openapi/{data_id}?KEY={YOUR_API_KEY}&AGE=21&Type=json&pIndex={page_num}&pSize=1000"
    laws = requests.get(url).json()[data_id][1]['row']
    all_laws.extend(laws)
all_laws = pd.DataFrame(all_laws)
all_laws.head()
# Out:
#                               BILL_ID  BILL_NO  \
# 0  PRC_M2V4T0T1S1Y5X0W9V4E5B0A6J0I1H0  2126297
# 1  PRC_Y2Y4X0X1F1G1E0C9D3B5C4Y4Y2X1V2  2126296
# 2  PRC_C2C4B0B1A1A1Z1H0H3F0G4E5F3D4E8  2126295
# 3  PRC_X2Y4X0V1V1U1U1C0D2B9Z3A9Y3Z1H0  2126294
# 4  PRC_L2L4J0K1G1E0E1D0E0C2C2K6J4J3I0  2126293
#
#                              BILL_NAME COMMITTEE  PROPOSE_DT PROC_RESULT AGE  \
# 0                마약류 관리에 관한 법률 일부개정법률안      None  2024-01-16        None  21
# 1                      국고금 관리법 일부개정법률안      None  2024-01-16        None  21
# 2                  국가과학기술자문회의법 일부개정법률안      None  2024-01-16        None  21
# 3  교원의 지위 향상 및 교육활동 보호를 위한 특별법 일부개정법률안      None  2024-01-16        None  21
# 4           연구개발특구의 육성에 관한 특별법 일부개정법률안      None  2024-01-16        None  21
#
#                                          DETAIL_LINK     PROPOSER  \
# 0  http://likms.assembly.go.kr/bill/billDetail.do...  한정애의원 등 10인
# 1  http://likms.assembly.go.kr/bill/billDetail.do...  김상훈의원 등 10인
# 2  http://likms.assembly.go.kr/bill/billDetail.do...  김도읍의원 등 12인
# 3  http://likms.assembly.go.kr/bill/billDetail.do...  김도읍의원 등 11인
# 4  http://likms.assembly.go.kr/bill/billDetail.do...  박성중의원 등 11인
#
#                                          MEMBER_LIST  ... LAW_SUBMIT_DT  \
# 0  http://likms.assembly.go.kr/bill/coactorListPo...  ...          None
# 1  http://likms.assembly.go.kr/bill/coactorListPo...  ...          None
# 2  http://likms.assembly.go.kr/bill/coactorListPo...  ...          None
# 3  http://likms.assembly.go.kr/bill/coactorListPo...  ...          None
# 4  http://likms.assembly.go.kr/bill/coactorListPo...  ...          None
#
#   CMT_PROC_RESULT_CD CMT_PROC_DT CMT_PRESENT_DT COMMITTEE_DT PROC_DT  \
# 0               None        None           None         None    None
# 1               None        None           None         None    None
# 2               None        None           None         None    None
# 3               None        None           None         None    None
# 4               None        None           None         None    None
#
#   COMMITTEE_ID                                PUBL_PROPOSER  \
# 0         None          윤미향,이원욱,김민석,김홍걸,강훈식,정성호,이성만,최인호,박홍근
# 1         None          조수진,김희곤,정희용,이종성,엄태영,김도읍,김형동,박대수,권영세
# 2         None  유경준,권명호,김석기,윤한홍,김병욱,김미애,권성동,지성호,박형수,유상범,장동혁
# 3         None      유경준,권명호,김석기,윤한홍,김병욱,권성동,지성호,박형수,유상범,장동혁
# 4         None     유경준,최춘식,이종성,양향자,김영식,태영호,황보승희,전봉민,김은희,이주환
#
#   LAW_PROC_RESULT_CD RST_PROPOSER
# 0               None          한정애
# 1               None          김상훈
# 2               None          김도읍
# 3               None          김도읍
# 4               None          박성중
#
# [5 rows x 22 columns]

# %%
# 혹시 날아갈까, 데이터를 파일로 저장하자.
all_laws.to_csv("all_laws.csv",index=False)

# %%
all_laws
# Out:
#                                   BILL_ID  BILL_NO  \
# 0      PRC_M2V4T0T1S1Y5X0W9V4E5B0A6J0I1H0  2126297
# 1      PRC_Y2Y4X0X1F1G1E0C9D3B5C4Y4Y2X1V2  2126296
# 2      PRC_C2C4B0B1A1A1Z1H0H3F0G4E5F3D4E8  2126295
# 3      PRC_X2Y4X0V1V1U1U1C0D2B9Z3A9Y3Z1H0  2126294
# 4      PRC_L2L4J0K1G1E0E1D0E0C2C2K6J4J3I0  2126293
# ...                                   ...      ...
# 23376  PRC_B2B0G0T6X0U1K1Q0O4J1N2F5Z0N2O4  2100005
# 23377  PRC_M2V0W0X6Y0Z1R1M0P1B4Q0C9S5U4D6  2100004
# 23378  PRC_X2T0K0O6X0Q1Y0S9M2L4W3O3J7O9H9  2100003
# 23379  PRC_X2P0C0O6K0J1F0V9R1K6F4T1X7Y6Q8  2100002
# 23380  PRC_H2T0Y0X6D0P1V0P9A1X1G5O8N3G1X0  2100001
#
#                                  BILL_NAME COMMITTEE  PROPOSE_DT PROC_RESULT  \
# 0                    마약류 관리에 관한 법률 일부개정법률안      None  2024-01-16        None
# 1                          국고금 관리법 일부개정법률안      None  2024-01-16        None
# 2                      국가과학기술자문회의법 일부개정법률안      None  2024-01-16        None
# 3      교원의 지위 향상 및 교육활동 보호를 위한 특별법 일부개정법률안      None  2024-01-16        None
# 4               연구개발특구의 육성에 관한 특별법 일부개정법률안      None  2024-01-16        None
# ...                                    ...       ...         ...         ...
# 23376                        고등교육법 일부개정법률안     교육위원회  2020-06-01      대안반영폐기
# 23377          감염병의 예방 및 관리에 관한 법률 일부개정법률안   보건복지위원회  2020-06-01        None
# 23378              장애인활동 지원에 관한 법률 일부개정법률안   보건복지위원회  2020-06-01        None
# 23379                        정부조직법 일부개정법률안   행정안전위원회  2020-06-01        None
# 23380             공공기관의 사회적 가치 실현에 관한 기본법안   기획재정위원회  2020-06-01        None
#
#       AGE                                        DETAIL_LINK      PROPOSER  \
# 0      21  http://likms.assembly.go.kr/bill/billDetail.do...   한정애의원 등 10인
# 1      21  http://likms.assembly.go.kr/bill/billDetail.do...   김상훈의원 등 10인
# 2      21  http://likms.assembly.go.kr/bill/billDetail.do...   김도읍의원 등 12인
# 3      21  http://likms.assembly.go.kr/bill/billDetail.do...   김도읍의원 등 11인
# 4      21  http://likms.assembly.go.kr/bill/billDetail.do...   박성중의원 등 11인
# ...    ..                                                ...           ...
# 23376  21  http://likms.assembly.go.kr/bill/billDetail.do...  이종배의원 등 103인
# 23377  21  http://likms.assembly.go.kr/bill/billDetail.do...  이종배의원 등 103인
# 23378  21  http://likms.assembly.go.kr/bill/billDetail.do...   장제원의원 등 12인
# 23379  21  http://likms.assembly.go.kr/bill/billDetail.do...   신현영의원 등 12인
# 23380  21  http://likms.assembly.go.kr/bill/billDetail.do...   박광온의원 등 16인
#
#                                              MEMBER_LIST  ... LAW_SUBMIT_DT  \
# 0      http://likms.assembly.go.kr/bill/coactorListPo...  ...          None
# 1      http://likms.assembly.go.kr/bill/coactorListPo...  ...          None
# 2      http://likms.assembly.go.kr/bill/coactorListPo...  ...          None
# 3      http://likms.assembly.go.kr/bill/coactorListPo...  ...          None
# 4      http://likms.assembly.go.kr/bill/coactorListPo...  ...          None
# ...                                                  ...  ...           ...
# 23376  http://likms.assembly.go.kr/bill/coactorListPo...  ...          None
# 23377  http://likms.assembly.go.kr/bill/coactorListPo...  ...          None
# 23378  http://likms.assembly.go.kr/bill/coactorListPo...  ...          None
# 23379  http://likms.assembly.go.kr/bill/coactorListPo...  ...          None
# 23380  http://likms.assembly.go.kr/bill/coactorListPo...  ...          None
#
#       CMT_PROC_RESULT_CD CMT_PROC_DT CMT_PRESENT_DT COMMITTEE_DT     PROC_DT  \
# 0                   None        None           None         None        None
# 1                   None        None           None         None        None
# 2                   None        None           None         None        None
# 3                   None        None           None         None        None
# 4                   None        None           None         None        None
# ...                  ...         ...            ...          ...         ...
# 23376             대안반영폐기  2020-09-22     2020-08-25   2020-06-29  2020-09-24
# 23377               None        None     2020-07-15   2020-06-16        None
# 23378               None        None     2020-07-15   2020-06-16        None
# 23379               None        None     2020-09-10   2020-06-29        None
# 23380               None        None     2020-09-21   2020-06-17        None
#
#       COMMITTEE_ID                                      PUBL_PROPOSER  \
# 0             None                윤미향,이원욱,김민석,김홍걸,강훈식,정성호,이성만,최인호,박홍근
# 1             None                조수진,김희곤,정희용,이종성,엄태영,김도읍,김형동,박대수,권영세
# 2             None        유경준,권명호,김석기,윤한홍,김병욱,김미애,권성동,지성호,박형수,유상범,장동혁
# 3             None            유경준,권명호,김석기,윤한홍,김병욱,권성동,지성호,박형수,유상범,장동혁
# 4             None           유경준,최춘식,이종성,양향자,김영식,태영호,황보승희,전봉민,김은희,이주환
# ...            ...                                                ...
# 23376      9700512  강기윤,강대식,강민국,곽상도,구자근,권명호,권영세,김기현,김도읍,김미애,김병욱,김상...
# 23377      9700341  강기윤,강대식,강민국,곽상도,구자근,권명호,권영세,김기현,김도읍,김미애,김병욱,김상...
# 23378      9700341        권성동,김정재,박덕흠,박성중,송석준,윤영석,윤한홍,이양수,이종배,추경호,홍문표
# 23379      9700480        고용진,김경만,김병욱,김병주,김성주,도종환,박병석,박홍근,안민석,유정주,이낙연
# 23380      9700300  강병원,권칠승,김두관,김영주,김정호,김진표,남인순,도종환,백혜련,송갑석,윤건영,이낙...
#
#       LAW_PROC_RESULT_CD RST_PROPOSER
# 0                   None          한정애
# 1                   None          김상훈
# 2                   None          김도읍
# 3                   None          김도읍
# 4                   None          박성중
# ...                  ...          ...
# 23376               None          이종배
# 23377               None          이종배
# 23378               None          장제원
# 23379               None          신현영
# 23380               None          박광온
#
# [23381 rows x 22 columns]

# %%
# 이번에는 국회의원들의 프로필을 털어보자.
data2_id = 'nwvrqwxyaytdsfvhu'
url =f"https://open.assembly.go.kr/portal/openapi/{data2_id}?KEY={YOUR_API_KEY}&Type=json&UNIT_CD=100020&pSize=1000"
senators = requests.get(url).json()[data2_id][1]['row']
senators = pd.DataFrame(senators)
senators
# Out:
#     HG_NM HJ_NM            ENG_NM BTH_GBN_NM    BTH_DATE JOB_RES_NM POLY_NM  \
# 0     강기윤   姜起潤        KANG GIYUN          양  1960-06-04         간사    국민의힘
# 1     강대식   姜大植       KANG DAESIK          양  1959-11-02         위원    국민의힘
# 2     강득구   姜得求       KANG DEUKGU          양  1963-05-27         위원  더불어민주당
# 3     강민국   姜旻局       KANG MINKUK          양  1971-03-03         위원    국민의힘
# 4     강민정   姜旼姃      KANG MINJUNG          양  1961-04-26         위원  더불어민주당
# ..    ...   ...               ...        ...         ...        ...     ...
# 293   홍익표   洪翼杓       HONG IHKPYO          양  1967-11-20        위원장  더불어민주당
# 294   홍정민   洪貞敏      HONG JUNGMIN          양  1978-11-24         위원  더불어민주당
# 295  황보승희  皇甫承希  HWANGBO SEUNGHEE          양  1976-08-05         위원     무소속
# 296   황운하   黃雲夏        HWANG UNHA          양  1962-09-10         위원  더불어민주당
# 297    황희    黃熙         HWANG HEE          양  1967-07-28         위원  더불어민주당
#
#        ORIG_NM ELECT_GBN_NM                       CMIT_NM  ... SEX_GBN_NM  \
# 0    경남 창원시성산구          지역구                       보건복지위원회  ...          남
# 1       대구 동구을          지역구                       국토교통위원회  ...          남
# 2    경기 안양시만안구          지역구              인구위기특별위원회, 교육위원회  ...          남
# 3      경남 진주시을          지역구                         정무위원회  ...          남
# 4         비례대표         비례대표                         교육위원회  ...          여
# ..         ...          ...                           ...  ...        ...
# 293  서울 중구성동구갑          지역구     문화체육관광위원회, 국회운영위원회, 정보위원회  ...          남
# 294    경기 고양시병          지역구  산업통상자원중소벤처기업위원회, 첨단전략산업특별위원회  ...          여
# 295   부산 중구영도구          지역구          문화체육관광위원회, 인구위기특별위원회  ...          여
# 296      대전 중구          지역구                         정무위원회  ...          남
# 297    서울 양천구갑          지역구                       외교통일위원회  ...          남
#
#                          TEL_NO                  E_MAIL  \
# 0                   02-784-1751        ggotop@naver.com
# 1                   02-784-5275      kds21341@naver.com
# 2                 02-784-2747~9    mainsail440@daum.net
# 3                   02-784-0797  strongwind01@naver.com
# 4                   02-784-2477    kmj2020edu@gmail.com
# ..                          ...                     ...
# 293                 02-784-6887     peace@peacehong.net
# 294                 02-784-8950     waytohong@naver.com
# 295  02-784-6931 / 051-412-0415      0415hbsh@naver.com
# 296                 02-784-1935     unhah0301@gmail.com
# 297                 02-784-8551  hwanghee6728@gmail.com
#
#                              HOMEPAGE     STAFF SECRETARY  \
# 0        http://blog.naver.com/ggotop  강현국, 한영애  김샛별, 장원종
# 1                                None  박홍규, 유진영  김기일, 이기백
# 2      http://blog.naver.com/dulipapa  김효성, 홍미하  장진수, 최경순
# 3                                None  강민승, 정경섭  김종민, 남정만
# 4     https://blog.naver.com/kmgedu21  손성조, 윤호숙  김민혜, 김원석
# ..                                ...       ...       ...
# 293          http://www.peacehong.net  신지희, 허정무  김진욱, 전해정
# 294  https://blog.naver.com/waytohong  엄소영, 이용남  김윤정, 정주영
# 295                              None  윤경남, 홍영민  고범욱, 김대원
# 296                              None  유승준, 정종훈  심대철, 장진섭
# 297  http://blog.naver.com/hwanghee67  나성채, 조주연  나종호, 배경민
#
#                   SECRETARY2   MONA_CD  \
# 0    안효상, 빈자영, 이유진, 김지훈, 조옥자  14M56632
# 1    박순권, 김광연, 김현정, 황인택, 정유미  L2I9861C
# 2    김창용, 오세령, 배은경, 남소영, 김광택  8P37634C
# 3    성환종, 이승연, 서경익, 윤정인, 정다정  GX22581L
# 4    김수안, 김성용, 민지홍, 황연미, 김기만  P2N50879
# ..                       ...       ...
# 293  김옥미, 이원종, 이상현, 김다예, 이아연  FRN1867O
# 294  김도영, 정윤주, 변민환, 이재환, 서연희  XA42275R
# 295  김성윤, 안지홍, 공채원, 김라희, 김보라  J9S37905
# 296       윤여진, 박병찬, 심준석, 나제임  0YT3774N
# 297  장유리, 김은지, 양지훈, 문경림, 신소라  0VU8517U
#
#                                              MEM_TITLE  ASSEM_ADDR
# 0    [학력]\r\n마산공고(26회)\r\n창원대학교 행정학과\r\n중앙대학교 행정대학원...   의원회관 937호
# 1    [학력]\r\n송정초등학교\r\n안심중학교\r\n경북대학교 사범대학 부속고등학교\r...   의원회관 341호
# 2    2023. 4.  ~ 현재      더불어민주당 정책위원회 상임부의장\r\n2023...   의원회관 440호
# 3    [학력]\r\n\r\n\r\n- 봉곡초등학교 졸업(14회)\r\n\r\n- 진주중학...  의원회관 1007호
# 4    현) 국회 교육위원회 위원\r\n\r\n전) 더불어민주당 원내소통부대표\r\n전) ...   의원회관 421호
# ..                                                 ...         ...
# 293  더불어민주당 원내대표(현)\r\n더불어민주당 서초구을지역위원장(현)\r\n\r\n[...   의원회관 839호
# 294  | 학력 | \r\n- 서울대학교 경제학부 졸업(2001년)\r\n- 서울대학교 경...   의원회관 326호
# 295  이화여자대학교 영어영문학\r\n영도여자고등학교\r\n\r\n(현) 제21대 국회의원...   의원회관 322호
# 296  <학력>\r\n대전산성초등학교\r\n동산중학교\r\n서대전고등학교\r\n경찰대학교 ...   의원회관 416호
# 297  2021.02~2022.05 문화체육관광부 장관\r\n2020.12~2021.02 ...   의원회관 838호
#
# [298 rows x 23 columns]

# %%
# 혹시 날아갈까, 데이터를 파일로 저장하자.
senators.to_csv("senators.csv",index=False)

# %%
# 아래는 같은 법률로 발의된 국회의원들의 조합을 찾아서, 그래프를 그리기 위한 데이터를 만드는 과정이다.
all_laws['PUBL_PROPOSER'] = all_laws['PUBL_PROPOSER']+','+all_laws['RST_PROPOSER']
all_laws['senator'] = all_laws['PUBL_PROPOSER'].str.split(',')
all_laws = all_laws[all_laws['senator'].notnull()]
pairs = all_laws['senator'].apply(lambda x: x if x is None else list(itertools.combinations(x,2))).explode()
pairs = pd.DataFrame(pairs.tolist(), columns=['Source', 'Target'])
pairs = pairs[pairs['Target'].notnull()]

# %%
# edge_list.csv 파일로 저장하자.
pairs.to_csv("edge_list.csv", index=False)

# %%
# 국회의원들은 노드 리스트로 만들어서 저장하자.
node_list = senators[['HG_NM','HG_NM', 'POLY_NM', 'ORIG_NM', 'SEX_GBN_NM']]
node_list.columns = ['Id','Label','Party','Local', 'Gender']
node_list.to_csv("node_list.csv",index=False)

# %% [markdown]
# ### [Gephi](https://gephi.org/)에서 실습?
